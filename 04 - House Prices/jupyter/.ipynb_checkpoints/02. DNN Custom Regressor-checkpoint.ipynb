# %%
import numpy as np
import pandas as pd
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)
# Out:
# C:\Users\vasil\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def load_datasets():
    # reading the datasets
    train = pd.read_csv('../input/train.csv.gz', compression='infer')
    infer = pd.read_csv('../input/test.csv.gz', compression='infer')
    
    train_features = train.drop(['Id','SalePrice'], axis=1)
    train_labels = train['SalePrice']
    infer_features = infer.drop('Id', axis=1)
    
    from sklearn.model_selection import train_test_split
    X_train, X_eval, y_train, y_eval = train_test_split(train_features, train_labels, test_size=0.15, random_state=42)
    
    def get_bins(df):
        bins = {}
        numeric_columns = [
            'LotFrontage', 'LotArea', 'TotalBsmtSF', 'BsmtFinSF2', 'BsmtUnfSF', 'WoodDeckSF',
            'BsmtFinSF1', 'MasVnrArea', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageArea',
            'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']
        
        for column in numeric_columns:
            tempdf, retbins = pd.cut(df[column], 10, labels=None, retbins=True, include_lowest=True)
            bins[column] = retbins

        return bins 
    
    bins = get_bins(X_train)
    
    labels, uniques = pd.factorize(['b', 'b', 'a', 'c', 'b'], sort=True)
    
    return X_train, X_eval, y_train, y_eval, infer_features, bins

X_train, X_eval, y_train, y_eval, infer_features, bins = load_datasets()

# %%
from tensorflow.feature_column import *

all_columns = X_train.columns
numeric_columns = [
        'LotFrontage', 'LotArea', 'TotalBsmtSF', 'BsmtFinSF2', 'BsmtUnfSF', 'WoodDeckSF',
        'BsmtFinSF1', 'MasVnrArea', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageArea',
        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']
categorical_columns = set(all_columns) - set(numeric_columns)

BUCKETIZED_FEATURES = [bucketized_column(numeric_column(column), boundaries=bins[column].tolist()) for column in 
                      numeric_columns]

CATEGORICAL_FEATURES = [categorical_column_with_identity(key=column, num_buckets=150) for column in categorical_columns]

FEATURE_COLUMNS = []
for feature in BUCKETIZED_FEATURES:
    FEATURE_COLUMNS.append(feature)
    
for feature in CATEGORICAL_FEATURES:
    FEATURE_COLUMNS.append(indicator_column(feature))
    
for column in categorical_columns:
    X_train[column], junk = pd.factorize(X_train[column])
    X_eval[column], junk = pd.factorize(X_eval[column])
    infer_features[column], junk = pd.factorize(infer_features[column])

# %%
def train_input_fn(features, labels):
    return tf.estimator.inputs.pandas_input_fn(
                x = features,
                y = labels,
                num_epochs = 1,
                shuffle = True,
                batch_size=50)

def eval_input_fn(features, labels):
    return tf.estimator.inputs.pandas_input_fn(
                x = features,
                y = labels,
                num_epochs = 1,
                shuffle = True)

def pred_input_fn(features):
    return tf.estimator.inputs.pandas_input_fn(
                x = features,
                num_epochs = 1,
                shuffle = False)

# %%
def model_fn(features, labels, mode, params):
    # mapping the feature columns as input layer
    net = tf.feature_column.input_layer(features, params['feature_columns'])
    
    # building the NN based on the list passed in 'hidden_units'
    for units in params['hidden_units']:
        net = tf.layers.dense(net, units=units, activation=tf.nn.relu)
        net = tf.layers.dropout(net, rate=0.1, training=True)
        
    # compute the result
    output_layer = tf.layers.dense(net, units=1)
    
    # Reshape the output layer to a 1-dim Tensor to return predictions
    value = tf.squeeze(output_layer, 1)
    
    # where to terminate if mode == predict
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=value)
    
    # computing the loss function

    loss = tf.sqrt(tf.losses.mean_squared_error(tf.log1p(labels), tf.log1p(value)))
    
    # where to terminate if mode == train
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer()
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)
    
    # where to terminate if mode == eval
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss)

# %%
OUTDIR = './DNN_CUSTOM_REGRESSOR'

file_writer = tf.summary.FileWriter(OUTDIR)

estimator = tf.estimator.Estimator(
    model_fn=model_fn, 
    model_dir=OUTDIR, 
    params={
        'feature_columns':FEATURE_COLUMNS,
        'hidden_units':[64,64,64,64,64,64]
    })
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './DNN_CUSTOM_REGRESSOR', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001F0AE1167F0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
def train_and_evaluate(estimator, epochs=50):
    for i in range(epochs):
        estimator.train(input_fn=train_input_fn(X_train,y_train.astype('float32')))
        estimator.evaluate(input_fn=eval_input_fn(X_eval,y_eval.astype('float32')))
        
train_and_evaluate(estimator)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 12.012163, step = 1
# INFO:tensorflow:Saving checkpoints for 25 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 8.290607.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:32:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-25
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:32:58
# INFO:tensorflow:Saving dict for global step 25: global_step = 25, loss = 8.01183
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25: ./DNN_CUSTOM_REGRESSOR\model.ckpt-25
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-25
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 25 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 7.9520764, step = 26
# INFO:tensorflow:Saving checkpoints for 50 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.805326.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:33:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:33:15
# INFO:tensorflow:Saving dict for global step 50: global_step = 50, loss = 4.727247
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50: ./DNN_CUSTOM_REGRESSOR\model.ckpt-50
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 50 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 4.620573, step = 51
# INFO:tensorflow:Saving checkpoints for 75 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5438693.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:33:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-75
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:33:31
# INFO:tensorflow:Saving dict for global step 75: global_step = 75, loss = 2.5478268
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 75: ./DNN_CUSTOM_REGRESSOR\model.ckpt-75
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-75
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 75 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 2.504003, step = 76
# INFO:tensorflow:Saving checkpoints for 100 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0100734.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:33:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:33:47
# INFO:tensorflow:Saving dict for global step 100: global_step = 100, loss = 1.0141188
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100: ./DNN_CUSTOM_REGRESSOR\model.ckpt-100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 100 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 1.0102924, step = 101
# INFO:tensorflow:Saving checkpoints for 125 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.45643398.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:34:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:34:02
# INFO:tensorflow:Saving dict for global step 125: global_step = 125, loss = 0.44563964
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 125: ./DNN_CUSTOM_REGRESSOR\model.ckpt-125
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 125 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.40662453, step = 126
# INFO:tensorflow:Saving checkpoints for 150 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.38955793.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:34:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:34:18
# INFO:tensorflow:Saving dict for global step 150: global_step = 150, loss = 0.43592885
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 150: ./DNN_CUSTOM_REGRESSOR\model.ckpt-150
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 150 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.35081095, step = 151
# INFO:tensorflow:Saving checkpoints for 175 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3991393.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:34:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-175
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:34:34
# INFO:tensorflow:Saving dict for global step 175: global_step = 175, loss = 0.43230414
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 175: ./DNN_CUSTOM_REGRESSOR\model.ckpt-175
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-175
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 175 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.39997995, step = 176
# INFO:tensorflow:Saving checkpoints for 200 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.28558227.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:34:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:34:51
# INFO:tensorflow:Saving dict for global step 200: global_step = 200, loss = 0.40634355
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: ./DNN_CUSTOM_REGRESSOR\model.ckpt-200
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 200 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.3406402, step = 201
# INFO:tensorflow:Saving checkpoints for 225 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.34037632.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:35:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:35:07
# INFO:tensorflow:Saving dict for global step 225: global_step = 225, loss = 0.38837332
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 225: ./DNN_CUSTOM_REGRESSOR\model.ckpt-225
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 225 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.2933016, step = 226
# INFO:tensorflow:Saving checkpoints for 250 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.24931335.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:35:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:35:23
# INFO:tensorflow:Saving dict for global step 250: global_step = 250, loss = 0.37388209
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 250: ./DNN_CUSTOM_REGRESSOR\model.ckpt-250
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 250 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.3190503, step = 251
# INFO:tensorflow:Saving checkpoints for 275 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3102802.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:35:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-275
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:35:39
# INFO:tensorflow:Saving dict for global step 275: global_step = 275, loss = 0.38560173
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 275: ./DNN_CUSTOM_REGRESSOR\model.ckpt-275
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-275
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 275 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.27539778, step = 276
# INFO:tensorflow:Saving checkpoints for 300 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.26741144.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:35:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:35:56
# INFO:tensorflow:Saving dict for global step 300: global_step = 300, loss = 0.3549202
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 300: ./DNN_CUSTOM_REGRESSOR\model.ckpt-300
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 300 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.3056717, step = 301
# INFO:tensorflow:Saving checkpoints for 325 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.17530675.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:36:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-325
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:36:12
# INFO:tensorflow:Saving dict for global step 325: global_step = 325, loss = 0.35861623
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 325: ./DNN_CUSTOM_REGRESSOR\model.ckpt-325
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-325
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 325 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.20946196, step = 326
# INFO:tensorflow:Saving checkpoints for 350 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.22433148.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:36:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-350
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:36:29
# INFO:tensorflow:Saving dict for global step 350: global_step = 350, loss = 0.3236441
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 350: ./DNN_CUSTOM_REGRESSOR\model.ckpt-350
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-350
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 350 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.22952683, step = 351
# INFO:tensorflow:Saving checkpoints for 375 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.17353313.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:36:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:36:45
# INFO:tensorflow:Saving dict for global step 375: global_step = 375, loss = 0.33599606
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 375: ./DNN_CUSTOM_REGRESSOR\model.ckpt-375
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 375 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.1915968, step = 376
# INFO:tensorflow:Saving checkpoints for 400 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20750694.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:36:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:37:01
# INFO:tensorflow:Saving dict for global step 400: global_step = 400, loss = 0.3327908
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: ./DNN_CUSTOM_REGRESSOR\model.ckpt-400
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 400 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.1795025, step = 401
# INFO:tensorflow:Saving checkpoints for 425 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13351703.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:37:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-425
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:37:18
# INFO:tensorflow:Saving dict for global step 425: global_step = 425, loss = 0.32148868
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 425: ./DNN_CUSTOM_REGRESSOR\model.ckpt-425
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-425
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 425 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.20529164, step = 426
# INFO:tensorflow:Saving checkpoints for 450 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13881643.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:37:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:37:34
# INFO:tensorflow:Saving dict for global step 450: global_step = 450, loss = 0.30145505
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 450: ./DNN_CUSTOM_REGRESSOR\model.ckpt-450
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 450 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.18790182, step = 451
# INFO:tensorflow:Saving checkpoints for 475 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18579306.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:37:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-475
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:37:50
# INFO:tensorflow:Saving dict for global step 475: global_step = 475, loss = 0.3034277
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 475: ./DNN_CUSTOM_REGRESSOR\model.ckpt-475
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-475
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 475 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.20590185, step = 476
# INFO:tensorflow:Saving checkpoints for 500 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.17752026.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:38:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:38:07
# INFO:tensorflow:Saving dict for global step 500: global_step = 500, loss = 0.29915074
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: ./DNN_CUSTOM_REGRESSOR\model.ckpt-500
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 500 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17717384, step = 501
# INFO:tensorflow:Saving checkpoints for 525 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.19852874.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:38:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-525
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:38:22
# INFO:tensorflow:Saving dict for global step 525: global_step = 525, loss = 0.3089762
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 525: ./DNN_CUSTOM_REGRESSOR\model.ckpt-525
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-525
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 525 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.21052389, step = 526
# INFO:tensorflow:Saving checkpoints for 550 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.24497645.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:38:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-550
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:38:38
# INFO:tensorflow:Saving dict for global step 550: global_step = 550, loss = 0.31608105
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 550: ./DNN_CUSTOM_REGRESSOR\model.ckpt-550
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-550
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 550 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17879775, step = 551
# INFO:tensorflow:Saving checkpoints for 575 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16867602.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:38:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-575
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:38:54
# INFO:tensorflow:Saving dict for global step 575: global_step = 575, loss = 0.30842412
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 575: ./DNN_CUSTOM_REGRESSOR\model.ckpt-575
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-575
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 575 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.157997, step = 576
# INFO:tensorflow:Saving checkpoints for 600 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.23297793.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:39:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:39:10
# INFO:tensorflow:Saving dict for global step 600: global_step = 600, loss = 0.30656767
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 600: ./DNN_CUSTOM_REGRESSOR\model.ckpt-600
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 600 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.16566366, step = 601
# INFO:tensorflow:Saving checkpoints for 625 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16018686.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:39:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:39:26
# INFO:tensorflow:Saving dict for global step 625: global_step = 625, loss = 0.30004156
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 625: ./DNN_CUSTOM_REGRESSOR\model.ckpt-625
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 625 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.18189019, step = 626
# INFO:tensorflow:Saving checkpoints for 650 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16344392.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:39:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-650
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:39:42
# INFO:tensorflow:Saving dict for global step 650: global_step = 650, loss = 0.30820048
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 650: ./DNN_CUSTOM_REGRESSOR\model.ckpt-650
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-650
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 650 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.16288286, step = 651
# INFO:tensorflow:Saving checkpoints for 675 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.1277055.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:39:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-675
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:39:57
# INFO:tensorflow:Saving dict for global step 675: global_step = 675, loss = 0.29986918
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 675: ./DNN_CUSTOM_REGRESSOR\model.ckpt-675
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-675
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 675 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.18408352, step = 676
# INFO:tensorflow:Saving checkpoints for 700 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.15882102.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:40:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:40:12
# INFO:tensorflow:Saving dict for global step 700: global_step = 700, loss = 0.29511583
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 700: ./DNN_CUSTOM_REGRESSOR\model.ckpt-700
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 700 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17287552, step = 701
# INFO:tensorflow:Saving checkpoints for 725 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13284148.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:40:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-725
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:40:29
# INFO:tensorflow:Saving dict for global step 725: global_step = 725, loss = 0.3106423
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 725: ./DNN_CUSTOM_REGRESSOR\model.ckpt-725
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-725
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 725 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.204811, step = 726
# INFO:tensorflow:Saving checkpoints for 750 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13225189.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:40:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:40:45
# INFO:tensorflow:Saving dict for global step 750: global_step = 750, loss = 0.28928208
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 750: ./DNN_CUSTOM_REGRESSOR\model.ckpt-750
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 750 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.16233453, step = 751
# INFO:tensorflow:Saving checkpoints for 775 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.12741914.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:40:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-775
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:41:00
# INFO:tensorflow:Saving dict for global step 775: global_step = 775, loss = 0.29843277
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 775: ./DNN_CUSTOM_REGRESSOR\model.ckpt-775
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-775
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 775 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.15084904, step = 776
# INFO:tensorflow:Saving checkpoints for 800 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.17932515.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:41:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:41:16
# INFO:tensorflow:Saving dict for global step 800: global_step = 800, loss = 0.3002519
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: ./DNN_CUSTOM_REGRESSOR\model.ckpt-800
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 800 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.1684135, step = 801
# INFO:tensorflow:Saving checkpoints for 825 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.123828284.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:41:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-825
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:41:31
# INFO:tensorflow:Saving dict for global step 825: global_step = 825, loss = 0.30076218
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 825: ./DNN_CUSTOM_REGRESSOR\model.ckpt-825
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-825
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 825 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17238301, step = 826
# INFO:tensorflow:Saving checkpoints for 850 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14344926.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:41:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-850
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:41:47
# INFO:tensorflow:Saving dict for global step 850: global_step = 850, loss = 0.28365734
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 850: ./DNN_CUSTOM_REGRESSOR\model.ckpt-850
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-850
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 850 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17667614, step = 851
# INFO:tensorflow:Saving checkpoints for 875 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16603221.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:42:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:42:02
# INFO:tensorflow:Saving dict for global step 875: global_step = 875, loss = 0.29020095
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 875: ./DNN_CUSTOM_REGRESSOR\model.ckpt-875
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 875 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.14125586, step = 876
# INFO:tensorflow:Saving checkpoints for 900 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.17271194.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:42:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:42:18
# INFO:tensorflow:Saving dict for global step 900: global_step = 900, loss = 0.30723
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 900: ./DNN_CUSTOM_REGRESSOR\model.ckpt-900
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 900 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.15759237, step = 901
# INFO:tensorflow:Saving checkpoints for 925 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16176215.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:42:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-925
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:42:34
# INFO:tensorflow:Saving dict for global step 925: global_step = 925, loss = 0.29454815
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 925: ./DNN_CUSTOM_REGRESSOR\model.ckpt-925
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-925
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 925 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.15549172, step = 926
# INFO:tensorflow:Saving checkpoints for 950 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.17765005.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:42:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-950
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:42:49
# INFO:tensorflow:Saving dict for global step 950: global_step = 950, loss = 0.31242245
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 950: ./DNN_CUSTOM_REGRESSOR\model.ckpt-950
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-950
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 950 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.16503504, step = 951
# INFO:tensorflow:Saving checkpoints for 975 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14573552.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:43:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:43:05
# INFO:tensorflow:Saving dict for global step 975: global_step = 975, loss = 0.29235208
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 975: ./DNN_CUSTOM_REGRESSOR\model.ckpt-975
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 975 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.19095044, step = 976
# INFO:tensorflow:Saving checkpoints for 1000 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18405423.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:43:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:43:20
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.29079863
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1000 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.15657558, step = 1001
# INFO:tensorflow:Saving checkpoints for 1025 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.15528621.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:43:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1025
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:43:36
# INFO:tensorflow:Saving dict for global step 1025: global_step = 1025, loss = 0.2948473
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1025: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1025
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1025
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1025 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.1577628, step = 1026
# INFO:tensorflow:Saving checkpoints for 1050 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.15527718.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:43:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1050
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:43:52
# INFO:tensorflow:Saving dict for global step 1050: global_step = 1050, loss = 0.29373392
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1050: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1050
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1050
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1050 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17090039, step = 1051
# INFO:tensorflow:Saving checkpoints for 1075 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.139812.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:44:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1075
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:44:08
# INFO:tensorflow:Saving dict for global step 1075: global_step = 1075, loss = 0.29339403
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1075: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1075
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1075
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1075 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17443192, step = 1076
# INFO:tensorflow:Saving checkpoints for 1100 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16712119.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:44:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:44:24
# INFO:tensorflow:Saving dict for global step 1100: global_step = 1100, loss = 0.2928866
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1100: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1100 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.15815605, step = 1101
# INFO:tensorflow:Saving checkpoints for 1125 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.19868247.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:44:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:44:40
# INFO:tensorflow:Saving dict for global step 1125: global_step = 1125, loss = 0.2965088
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1125: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1125
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1125 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.15184891, step = 1126
# INFO:tensorflow:Saving checkpoints for 1150 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13275544.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:44:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:44:56
# INFO:tensorflow:Saving dict for global step 1150: global_step = 1150, loss = 0.29414263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1150: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1150
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1150 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.14007987, step = 1151
# INFO:tensorflow:Saving checkpoints for 1175 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14894757.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:45:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1175
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:45:12
# INFO:tensorflow:Saving dict for global step 1175: global_step = 1175, loss = 0.3116
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1175: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1175
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1175
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1175 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.17611596, step = 1176
# INFO:tensorflow:Saving checkpoints for 1200 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.15862432.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:45:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:45:28
# INFO:tensorflow:Saving dict for global step 1200: global_step = 1200, loss = 0.2873449
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1200
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1200 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.1519541, step = 1201
# INFO:tensorflow:Saving checkpoints for 1225 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14197008.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:45:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:45:44
# INFO:tensorflow:Saving dict for global step 1225: global_step = 1225, loss = 0.30373043
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1225: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1225
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1225 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:loss = 0.13139826, step = 1226
# INFO:tensorflow:Saving checkpoints for 1250 into ./DNN_CUSTOM_REGRESSOR\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14332682.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-12-13:45:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CUSTOM_REGRESSOR\model.ckpt-1250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-12-13:46:00
# INFO:tensorflow:Saving dict for global step 1250: global_step = 1250, loss = 0.2834935
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1250: ./DNN_CUSTOM_REGRESSOR\model.ckpt-1250

# %%
generator = estimator.predict(input_fn=pred_input_fn(infer_features))
predictions = [next(generator) for i in range(len(infer_features))]

# %%
ids = pd.read_csv('../input/test.csv.gz', compression='infer')['Id']

submission = pd.DataFrame()
submission['SalePrice'] = predictions
submission['Id'] = ids
submission.set_index('Id', inplace=True)

submission.to_csv('../output/07.dnn_custom_regressor[128x5]_50_epochs_dropout.csv')
