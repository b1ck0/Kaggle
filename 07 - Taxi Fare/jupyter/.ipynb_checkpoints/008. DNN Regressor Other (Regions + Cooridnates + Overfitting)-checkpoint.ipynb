# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,10)

# %%
def read_csv(TRAIN_PATH):
    chunksize = 5_000_000 # batch size
    
    traintypes = {
        'fare': 'float32',
        'from': 'str',
        'to': 'str',
        'p_count': 'uint8', 
        'hour': 'uint8',
        'weekday': 'uint8',
        'week': 'uint8',
        'year': 'int16',
        'dist_e': 'float32',
        'dist_t': 'float32',
        'x0': 'float32',
        'x1': 'float32',
        'y0': 'float32',
        'y1': 'float32',
    }
    
    cols = list(traintypes.keys())
    
    # loading the dataframe into list of small dataframes
    df_list = []

    for df_chunk in pd.read_csv(TRAIN_PATH, usecols=cols, dtype=traintypes, chunksize=chunksize):
        df_list.append(df_chunk) 
        df = pd.concat(df_list)
        
    return df

# %%
train = read_csv('../input/train_cleaned_2.csv')

# %%
train = train[(train['from'] == 'Manhattan') & (train['to'] == 'Manhattan')]

# %%
train.shape
# Out:
# (46123235, 14)

# %%
y = train['fare']
X = train.drop(['fare'], axis=1)
del train

from sklearn.model_selection import train_test_split
X_train, X_eval, y_train, y_eval = train_test_split(X, y, test_size=0.25, random_state=379582)

del X,y

# %%
import tensorflow as tf

# %%
# num_buckets = [0, num_buckets)
p_count = tf.feature_column.numeric_column('p_count')
taxicab = tf.feature_column.numeric_column('dist_t')
euclidean = tf.feature_column.numeric_column('dist_e')

x0 = tf.feature_column.numeric_column('x0')
x1 = tf.feature_column.numeric_column('x1')
y0 = tf.feature_column.numeric_column('y0')
y1 = tf.feature_column.numeric_column('y1')

numbuckets = 30
dx = np.linspace(-74.019108, -73.928684, numbuckets).tolist()
dy = np.linspace(40.700316, 40.877544, numbuckets).tolist()

x0_B = tf.feature_column.bucketized_column(x0, dx)
x1_B = tf.feature_column.bucketized_column(x1, dx)
y0_B = tf.feature_column.bucketized_column(y0, dy)
y1_B = tf.feature_column.bucketized_column(y1, dy)

xy_0 = tf.feature_column.crossed_column([x0_B, y0_B], numbuckets * numbuckets)
xy_1 = tf.feature_column.crossed_column([x1_B, y1_B], numbuckets * numbuckets)
xy_pair = tf.feature_column.crossed_column([xy_0, xy_1], numbuckets**4)

# definition of the categorical columns
hour = tf.feature_column.categorical_column_with_identity('hour', num_buckets = 24)
weekday = tf.feature_column.categorical_column_with_identity('weekday', num_buckets = 7)
week = tf.feature_column.categorical_column_with_identity('week', num_buckets = 54)
year = tf.feature_column.categorical_column_with_vocabulary_list('year', [2009, 2010, 2011, 2012, 2013, 2014, 2015])

# definition of the feature crosses
hour_weekday = tf.feature_column.crossed_column([hour, weekday], 24 * 7)
weekday_week_year = tf.feature_column.crossed_column([weekday, week, year], 7 * 54 * 7)
week_year = tf.feature_column.crossed_column([week, year], 54 * 7)
weekday_year = tf.feature_column.crossed_column([weekday, year], 7 * 7)
hour_weekday_year = tf.feature_column.crossed_column([hour, weekday, year], 24 * 7 * 7)

# %%
deep_columns = [
    # Embedding_column to "group" together ...
    tf.feature_column.embedding_column(hour_weekday, 50),
    tf.feature_column.embedding_column(weekday_week_year, 50),
    tf.feature_column.embedding_column(week_year, 50),
    tf.feature_column.embedding_column(weekday_year, 50),
    tf.feature_column.embedding_column(hour_weekday_year, 50),
    tf.feature_column.embedding_column(xy_pair, 50),

    # indicator columns
    tf.feature_column.indicator_column(hour),
    tf.feature_column.indicator_column(weekday),
    tf.feature_column.indicator_column(week),
    tf.feature_column.indicator_column(year),
    tf.feature_column.indicator_column(xy_0),
    tf.feature_column.indicator_column(xy_1),

    # numeric columns
    taxicab, euclidean, p_count
]

# %%
def train_input_fn(features, labels, batch_size):
    return tf.estimator.inputs.pandas_input_fn(
        x = features,
        y = labels,
        num_epochs = 1,
        shuffle = True,
        batch_size = batch_size)

def eval_input_fn(features, labels):
    return tf.estimator.inputs.pandas_input_fn(
        x = features,
        y = labels,
        num_epochs = 1,
        shuffle = True)

def pred_input_fn(features):
    return tf.estimator.inputs.pandas_input_fn(
        x = features,
        num_epochs = 1,
        shuffle = False)

# %%
model_dir = './DNN_Regressor_manhattan'

file_writer = tf.summary.FileWriter(model_dir)

estimator = tf.estimator.DNNRegressor(
    model_dir = model_dir,
    feature_columns = deep_columns,
    optimizer = tf.train.AdamOptimizer(learning_rate=0.0001),
    hidden_units = [128,128,128,128], 
    batch_norm = True,
)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './DNN_Regressor_manhattan', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001F8559F1198>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
train_spec = tf.estimator.TrainSpec(input_fn = train_input_fn(X_train, y_train, batch_size=2500))
eval_spec = tf.estimator.EvalSpec(input_fn = eval_input_fn(X_eval, y_eval))

# %%
for i in range(1):
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./DNN_Regressor_manhattan\model.ckpt.
# INFO:tensorflow:loss = 268322.38, step = 0
# INFO:tensorflow:global_step/sec: 6.71512
# INFO:tensorflow:loss = 216159.89, step = 100 (14.894 sec)
# INFO:tensorflow:global_step/sec: 7.23428
# INFO:tensorflow:loss = 195271.53, step = 200 (13.822 sec)
# INFO:tensorflow:global_step/sec: 7.23445
# INFO:tensorflow:loss = 192898.98, step = 300 (13.822 sec)
# INFO:tensorflow:global_step/sec: 7.08391
# INFO:tensorflow:loss = 181200.47, step = 400 (14.118 sec)
# INFO:tensorflow:global_step/sec: 7.12521
# INFO:tensorflow:loss = 178458.88, step = 500 (14.035 sec)
# INFO:tensorflow:global_step/sec: 7.15628
# INFO:tensorflow:loss = 159603.56, step = 600 (13.974 sec)
# INFO:tensorflow:global_step/sec: 7.10788
# INFO:tensorflow:loss = 145564.95, step = 700 (14.069 sec)
# INFO:tensorflow:global_step/sec: 7.03973
# INFO:tensorflow:loss = 140782.81, step = 800 (14.214 sec)
# INFO:tensorflow:global_step/sec: 7.10146
# INFO:tensorflow:loss = 122267.13, step = 900 (14.073 sec)
# INFO:tensorflow:global_step/sec: 7.18313
# INFO:tensorflow:loss = 93862.16, step = 1000 (13.921 sec)
# INFO:tensorflow:global_step/sec: 7.18705
# INFO:tensorflow:loss = 101262.43, step = 1100 (13.914 sec)
# INFO:tensorflow:global_step/sec: 7.10786
# INFO:tensorflow:loss = 78497.75, step = 1200 (14.069 sec)
# INFO:tensorflow:global_step/sec: 7.32842
# INFO:tensorflow:loss = 63402.414, step = 1300 (13.646 sec)
# INFO:tensorflow:global_step/sec: 7.54308
# INFO:tensorflow:loss = 53699.39, step = 1400 (13.257 sec)
# INFO:tensorflow:global_step/sec: 7.41882
# INFO:tensorflow:loss = 45149.195, step = 1500 (13.478 sec)
# INFO:tensorflow:global_step/sec: 7.24197
# INFO:tensorflow:loss = 37823.785, step = 1600 (13.809 sec)
# INFO:tensorflow:global_step/sec: 7.19963
# INFO:tensorflow:loss = 32522.605, step = 1700 (13.899 sec)
# INFO:tensorflow:global_step/sec: 6.96974
# INFO:tensorflow:loss = 21604.74, step = 1800 (14.339 sec)
# INFO:tensorflow:global_step/sec: 7.20666
# INFO:tensorflow:loss = 26169.92, step = 1900 (13.876 sec)
# INFO:tensorflow:global_step/sec: 7.1142
# INFO:tensorflow:loss = 26974.168, step = 2000 (14.056 sec)
# INFO:tensorflow:global_step/sec: 7.19554
# INFO:tensorflow:loss = 17795.904, step = 2100 (13.896 sec)
# INFO:tensorflow:global_step/sec: 7.12007
# INFO:tensorflow:loss = 15098.674, step = 2200 (14.047 sec)
# INFO:tensorflow:global_step/sec: 7.05811
# INFO:tensorflow:loss = 16012.511, step = 2300 (14.167 sec)
# INFO:tensorflow:global_step/sec: 7.10139
# INFO:tensorflow:loss = 20017.943, step = 2400 (14.083 sec)
# INFO:tensorflow:global_step/sec: 7.10881
# INFO:tensorflow:loss = 22856.758, step = 2500 (14.066 sec)
# INFO:tensorflow:global_step/sec: 7.03986
# INFO:tensorflow:loss = 14655.75, step = 2600 (14.213 sec)
# INFO:tensorflow:global_step/sec: 7.17266
# INFO:tensorflow:loss = 23000.734, step = 2700 (13.934 sec)
# INFO:tensorflow:global_step/sec: 7.34253
# INFO:tensorflow:loss = 16361.583, step = 2800 (13.619 sec)
# INFO:tensorflow:global_step/sec: 7.38406
# INFO:tensorflow:loss = 16181.926, step = 2900 (13.543 sec)
# INFO:tensorflow:global_step/sec: 7.44217
# INFO:tensorflow:loss = 22526.107, step = 3000 (13.437 sec)
# INFO:tensorflow:global_step/sec: 7.19355
# INFO:tensorflow:loss = 15736.559, step = 3100 (13.901 sec)
# INFO:tensorflow:global_step/sec: 7.25598
# INFO:tensorflow:loss = 15794.303, step = 3200 (13.781 sec)
# INFO:tensorflow:global_step/sec: 7.20094
# INFO:tensorflow:loss = 23065.953, step = 3300 (13.887 sec)
# INFO:tensorflow:global_step/sec: 7.32002
# INFO:tensorflow:loss = 17891.646, step = 3400 (13.661 sec)
# INFO:tensorflow:global_step/sec: 7.2368
# INFO:tensorflow:loss = 17313.076, step = 3500 (13.826 sec)
# INFO:tensorflow:global_step/sec: 7.43794
# INFO:tensorflow:loss = 24224.047, step = 3600 (13.437 sec)
# INFO:tensorflow:global_step/sec: 7.13918
# INFO:tensorflow:loss = 12618.53, step = 3700 (14.007 sec)
# INFO:tensorflow:global_step/sec: 7.30707
# INFO:tensorflow:loss = 23009.426, step = 3800 (13.684 sec)
# INFO:tensorflow:global_step/sec: 7.26093
# INFO:tensorflow:loss = 25046.506, step = 3900 (13.773 sec)
# INFO:tensorflow:global_step/sec: 7.34697
# INFO:tensorflow:loss = 16829.717, step = 4000 (13.611 sec)
# INFO:tensorflow:global_step/sec: 7.3764
# INFO:tensorflow:loss = 19505.846, step = 4100 (13.557 sec)
# INFO:tensorflow:global_step/sec: 7.35032
# INFO:tensorflow:loss = 14219.653, step = 4200 (13.605 sec)
# INFO:tensorflow:global_step/sec: 7.37848
# INFO:tensorflow:loss = 35854.44, step = 4300 (13.552 sec)
# INFO:tensorflow:Saving checkpoints for 4315 into ./DNN_Regressor_manhattan\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-04-21:01:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_Regressor_manhattan\model.ckpt-4315
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-04-21:01:31
# INFO:tensorflow:Saving dict for global step 4315: average_loss = 9.382259, global_step = 4315, label/mean = 8.986766, loss = 1200.9292, prediction/mean = 8.807549
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4315: ./DNN_Regressor_manhattan\model.ckpt-4315
# INFO:tensorflow:global_step/sec: 4.773
# INFO:tensorflow:loss = 17775.66, step = 4400 (20.961 sec)
# INFO:tensorflow:global_step/sec: 7.38696
# INFO:tensorflow:loss = 15793.952, step = 4500 (13.529 sec)
# INFO:tensorflow:global_step/sec: 7.37531
# INFO:tensorflow:loss = 13903.958, step = 4600 (13.560 sec)
# INFO:tensorflow:global_step/sec: 7.36924
# INFO:tensorflow:loss = 11698.002, step = 4700 (13.569 sec)
# INFO:tensorflow:global_step/sec: 7.3765
# INFO:tensorflow:loss = 17018.9, step = 4800 (13.557 sec)
# INFO:tensorflow:global_step/sec: 7.38451
# INFO:tensorflow:loss = 23518.14, step = 4900 (13.542 sec)
# INFO:tensorflow:global_step/sec: 7.34086
# INFO:tensorflow:loss = 13889.894, step = 5000 (13.623 sec)
# INFO:tensorflow:global_step/sec: 7.32878
# INFO:tensorflow:loss = 25171.266, step = 5100 (13.644 sec)
# INFO:tensorflow:global_step/sec: 7.25195
# INFO:tensorflow:loss = 18609.117, step = 5200 (13.789 sec)
# INFO:tensorflow:global_step/sec: 7.36826
# INFO:tensorflow:loss = 19582.201, step = 5300 (13.579 sec)
# INFO:tensorflow:global_step/sec: 7.31372
# INFO:tensorflow:loss = 17302.502, step = 5400 (13.666 sec)
# INFO:tensorflow:global_step/sec: 7.36316
# INFO:tensorflow:loss = 15741.55, step = 5500 (13.581 sec)
# INFO:tensorflow:global_step/sec: 7.36933
# INFO:tensorflow:loss = 16211.043, step = 5600 (13.570 sec)
# INFO:tensorflow:global_step/sec: 7.38919
# INFO:tensorflow:loss = 15131.277, step = 5700 (13.533 sec)
# INFO:tensorflow:global_step/sec: 7.34492
# INFO:tensorflow:loss = 12601.932, step = 5800 (13.615 sec)
# INFO:tensorflow:global_step/sec: 7.34837
# INFO:tensorflow:loss = 12866.589, step = 5900 (13.608 sec)
# INFO:tensorflow:global_step/sec: 7.37519
# INFO:tensorflow:loss = 13860.403, step = 6000 (13.559 sec)
# INFO:tensorflow:global_step/sec: 7.37594
# INFO:tensorflow:loss = 16452.77, step = 6100 (13.557 sec)
# INFO:tensorflow:global_step/sec: 7.37594
# INFO:tensorflow:loss = 22069.297, step = 6200 (13.566 sec)
# INFO:tensorflow:global_step/sec: 7.359
# INFO:tensorflow:loss = 13963.18, step = 6300 (13.582 sec)
# INFO:tensorflow:global_step/sec: 7.36169
# INFO:tensorflow:loss = 11505.047, step = 6400 (13.583 sec)
# INFO:tensorflow:global_step/sec: 7.31575
# INFO:tensorflow:loss = 18119.562, step = 6500 (13.670 sec)
# INFO:tensorflow:global_step/sec: 7.40088
# INFO:tensorflow:loss = 19065.648, step = 6600 (13.512 sec)
# INFO:tensorflow:global_step/sec: 7.39325
# INFO:tensorflow:loss = 16822.85, step = 6700 (13.527 sec)
# INFO:tensorflow:global_step/sec: 7.36253
# INFO:tensorflow:loss = 19988.008, step = 6800 (13.581 sec)
# INFO:tensorflow:global_step/sec: 7.37446
# INFO:tensorflow:loss = 13018.806, step = 6900 (13.560 sec)
# INFO:tensorflow:global_step/sec: 7.3457
# INFO:tensorflow:loss = 15894.525, step = 7000 (13.613 sec)
# INFO:tensorflow:global_step/sec: 7.30883
# INFO:tensorflow:loss = 14577.035, step = 7100 (13.690 sec)
# INFO:tensorflow:global_step/sec: 7.35868
# INFO:tensorflow:loss = 13697.546, step = 7200 (13.581 sec)
# INFO:tensorflow:global_step/sec: 7.26922
# INFO:tensorflow:loss = 11699.647, step = 7300 (13.757 sec)
# INFO:tensorflow:global_step/sec: 7.39065
# INFO:tensorflow:loss = 26525.164, step = 7400 (13.531 sec)
# INFO:tensorflow:global_step/sec: 7.35033
# INFO:tensorflow:loss = 12724.57, step = 7500 (13.605 sec)
# INFO:tensorflow:global_step/sec: 7.33491
# INFO:tensorflow:loss = 15273.261, step = 7600 (13.633 sec)
# INFO:tensorflow:global_step/sec: 7.34534
# INFO:tensorflow:loss = 14057.866, step = 7700 (13.614 sec)
# INFO:tensorflow:global_step/sec: 7.42793
# INFO:tensorflow:loss = 17245.318, step = 7800 (13.463 sec)
# INFO:tensorflow:global_step/sec: 7.38464
# INFO:tensorflow:loss = 13220.348, step = 7900 (13.542 sec)
# INFO:tensorflow:global_step/sec: 6.91956
# INFO:tensorflow:loss = 12415.212, step = 8000 (14.459 sec)
# INFO:tensorflow:global_step/sec: 7.03283
# INFO:tensorflow:loss = 13350.84, step = 8100 (14.211 sec)
# INFO:tensorflow:global_step/sec: 7.2056
# INFO:tensorflow:loss = 19384.11, step = 8200 (13.878 sec)
# INFO:tensorflow:global_step/sec: 7.24621
# INFO:tensorflow:loss = 13856.566, step = 8300 (13.802 sec)
# INFO:tensorflow:global_step/sec: 7.14389
# INFO:tensorflow:loss = 20829.354, step = 8400 (13.996 sec)
# INFO:tensorflow:global_step/sec: 7.2201
# INFO:tensorflow:loss = 13054.432, step = 8500 (13.850 sec)
# INFO:tensorflow:global_step/sec: 7.17947
# INFO:tensorflow:loss = 16403.227, step = 8600 (13.929 sec)
# INFO:tensorflow:Saving checkpoints for 8652 into ./DNN_Regressor_manhattan\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-04-21:11:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_Regressor_manhattan\model.ckpt-8652
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-04-21:11:31
# INFO:tensorflow:Saving dict for global step 8652: average_loss = 6.471217, global_step = 8652, label/mean = 8.846121, loss = 828.3158, prediction/mean = 8.968044
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8652: ./DNN_Regressor_manhattan\model.ckpt-8652
# INFO:tensorflow:global_step/sec: 4.83213
# INFO:tensorflow:loss = 19814.332, step = 8700 (20.696 sec)
# INFO:tensorflow:global_step/sec: 7.38742
# INFO:tensorflow:loss = 24585.6, step = 8800 (13.537 sec)
# INFO:tensorflow:global_step/sec: 7.37417
# INFO:tensorflow:loss = 14548.55, step = 8900 (13.574 sec)
# INFO:tensorflow:global_step/sec: 7.35795
# INFO:tensorflow:loss = 16176.647, step = 9000 (13.578 sec)
# INFO:tensorflow:global_step/sec: 7.40281
# INFO:tensorflow:loss = 22509.322, step = 9100 (13.509 sec)
# INFO:tensorflow:global_step/sec: 7.25739
# INFO:tensorflow:loss = 17202.248, step = 9200 (13.777 sec)
# INFO:tensorflow:global_step/sec: 7.17117
# INFO:tensorflow:loss = 26780.94, step = 9300 (13.946 sec)
# INFO:tensorflow:global_step/sec: 7.23639
# INFO:tensorflow:loss = 27887.957, step = 9400 (13.819 sec)
# INFO:tensorflow:global_step/sec: 6.98726
# INFO:tensorflow:loss = 20831.732, step = 9500 (14.312 sec)
# INFO:tensorflow:global_step/sec: 7.08483
# INFO:tensorflow:loss = 10771.092, step = 9600 (14.115 sec)
# INFO:tensorflow:global_step/sec: 7.26668
# INFO:tensorflow:loss = 17735.408, step = 9700 (13.761 sec)
# INFO:tensorflow:global_step/sec: 7.29796
# INFO:tensorflow:loss = 23483.129, step = 9800 (13.710 sec)
# INFO:tensorflow:global_step/sec: 7.32117
# INFO:tensorflow:loss = 15649.07, step = 9900 (13.651 sec)
# INFO:tensorflow:global_step/sec: 7.01817
# INFO:tensorflow:loss = 11160.406, step = 10000 (14.249 sec)
# INFO:tensorflow:global_step/sec: 7.24406
# INFO:tensorflow:loss = 20364.287, step = 10100 (13.804 sec)
# INFO:tensorflow:global_step/sec: 7.35547
# INFO:tensorflow:loss = 15731.554, step = 10200 (13.595 sec)
# INFO:tensorflow:global_step/sec: 7.37371
# INFO:tensorflow:loss = 14977.562, step = 10300 (13.562 sec)
# INFO:tensorflow:global_step/sec: 7.37966
# INFO:tensorflow:loss = 23969.877, step = 10400 (13.551 sec)
# INFO:tensorflow:global_step/sec: 7.30935
# INFO:tensorflow:loss = 16431.168, step = 10500 (13.681 sec)
# INFO:tensorflow:global_step/sec: 7.30767
# INFO:tensorflow:loss = 33208.652, step = 10600 (13.684 sec)
# INFO:tensorflow:global_step/sec: 7.09876
# INFO:tensorflow:loss = 13774.473, step = 10700 (14.094 sec)
# INFO:tensorflow:global_step/sec: 7.27356
# INFO:tensorflow:loss = 17718.303, step = 10800 (13.741 sec)
# INFO:tensorflow:global_step/sec: 7.30103
# INFO:tensorflow:loss = 12702.455, step = 10900 (13.697 sec)
# INFO:tensorflow:global_step/sec: 7.37282
# INFO:tensorflow:loss = 13854.479, step = 11000 (13.564 sec)
# INFO:tensorflow:global_step/sec: 7.37475
# INFO:tensorflow:loss = 9042.48, step = 11100 (13.559 sec)
# INFO:tensorflow:global_step/sec: 7.36971
# INFO:tensorflow:loss = 23054.6, step = 11200 (13.569 sec)
# INFO:tensorflow:global_step/sec: 7.36953
# INFO:tensorflow:loss = 11474.201, step = 11300 (13.569 sec)
# INFO:tensorflow:global_step/sec: 7.3512
# INFO:tensorflow:loss = 13468.448, step = 11400 (13.603 sec)
# INFO:tensorflow:global_step/sec: 7.33648
# INFO:tensorflow:loss = 17701.258, step = 11500 (13.631 sec)
# INFO:tensorflow:global_step/sec: 7.27587
# INFO:tensorflow:loss = 14248.527, step = 11600 (13.752 sec)
# INFO:tensorflow:global_step/sec: 7.27521
# INFO:tensorflow:loss = 15564.381, step = 11700 (13.736 sec)
# INFO:tensorflow:global_step/sec: 7.17732
# INFO:tensorflow:loss = 15018.98, step = 11800 (13.934 sec)
# INFO:tensorflow:global_step/sec: 7.22914
# INFO:tensorflow:loss = 19288.875, step = 11900 (13.833 sec)
# INFO:tensorflow:global_step/sec: 7.30214
# INFO:tensorflow:loss = 25085.264, step = 12000 (13.696 sec)
# INFO:tensorflow:global_step/sec: 7.37599
# INFO:tensorflow:loss = 23400.287, step = 12100 (13.556 sec)
# INFO:tensorflow:global_step/sec: 7.38192
# INFO:tensorflow:loss = 18286.727, step = 12200 (13.548 sec)
# INFO:tensorflow:global_step/sec: 7.37499
# INFO:tensorflow:loss = 13430.781, step = 12300 (13.559 sec)
# INFO:tensorflow:global_step/sec: 7.34833
# INFO:tensorflow:loss = 12094.674, step = 12400 (13.609 sec)
# INFO:tensorflow:global_step/sec: 7.08533
# INFO:tensorflow:loss = 19952.979, step = 12500 (14.125 sec)
# INFO:tensorflow:global_step/sec: 7.00081
# INFO:tensorflow:loss = 25721.223, step = 12600 (14.273 sec)
# INFO:tensorflow:global_step/sec: 7.32725
# INFO:tensorflow:loss = 18830.895, step = 12700 (13.649 sec)
# INFO:tensorflow:global_step/sec: 7.27843
# INFO:tensorflow:loss = 20637.422, step = 12800 (13.738 sec)
# INFO:tensorflow:global_step/sec: 6.93969
# INFO:tensorflow:loss = 13563.149, step = 12900 (14.410 sec)
# INFO:tensorflow:Saving checkpoints for 12961 into ./DNN_Regressor_manhattan\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-04-21:21:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_Regressor_manhattan\model.ckpt-12961
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-04-21:21:32
# INFO:tensorflow:Saving dict for global step 12961: average_loss = 7.100344, global_step = 12961, label/mean = 8.933156, loss = 908.84406, prediction/mean = 9.02547
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12961: ./DNN_Regressor_manhattan\model.ckpt-12961
# INFO:tensorflow:global_step/sec: 4.62697
# INFO:tensorflow:loss = 16569.594, step = 13000 (21.612 sec)
# INFO:tensorflow:global_step/sec: 7.30489
# INFO:tensorflow:loss = 17635.031, step = 13100 (13.689 sec)
# INFO:tensorflow:global_step/sec: 7.31135
# INFO:tensorflow:loss = 14980.781, step = 13200 (13.677 sec)
# INFO:tensorflow:global_step/sec: 7.33378
# INFO:tensorflow:loss = 17465.24, step = 13300 (13.636 sec)
# INFO:tensorflow:global_step/sec: 7.31403
# INFO:tensorflow:loss = 21117.553, step = 13400 (13.680 sec)
# INFO:tensorflow:global_step/sec: 7.01845
# INFO:tensorflow:loss = 15907.113, step = 13500 (14.240 sec)
# INFO:tensorflow:global_step/sec: 7.24476
# INFO:tensorflow:loss = 16722.7, step = 13600 (13.803 sec)
# INFO:tensorflow:global_step/sec: 7.11067
# INFO:tensorflow:loss = 21092.656, step = 13700 (14.063 sec)
# INFO:tensorflow:global_step/sec: 7.09804
# INFO:tensorflow:loss = 14240.436, step = 13800 (14.087 sec)
# INFO:tensorflow:Saving checkpoints for 13837 into ./DNN_Regressor_manhattan\model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (600 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-04-21:23:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_Regressor_manhattan\model.ckpt-13837
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-04-21:23:41
# INFO:tensorflow:Saving dict for global step 13837: average_loss = 5.914935, global_step = 13837, label/mean = 8.876732, loss = 757.1117, prediction/mean = 8.999346
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13837: ./DNN_Regressor_manhattan\model.ckpt-13837
# INFO:tensorflow:Loss for final step: 17336.883.

# %%
infer = pd.read_csv('../input/test_processed.csv', index_col='key')

generator = estimator.predict(input_fn=pred_input_fn(infer))
predictions = [next(generator) for i in range(len(infer))]
values = [val['predictions'].tolist()[0] for val in predictions]

ids = infer.index
submission = pd.DataFrame()
submission['fare_amount'] = values
submission['key'] = ids
submission.set_index('key', inplace=True)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_Regressor_manhattan\model.ckpt-13837
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
locations = [
    'Manhattan', 'JFK', 'LaGardia', 'Newark', 'Teterboro', 'Brooklin', 'Bronx', 'Staten', 'Queens', 'Westchester',
    'Nassau', 'Jersey', 'Bayonne', 'WStaton', 'West', 'WNewYork', 'North'        
]

# num_buckets = [0, num_buckets)

p_count = tf.feature_column.numeric_column('p_count')
taxicab = tf.feature_column.numeric_column('dist_t')
euclidean = tf.feature_column.numeric_column('dist_e')

x0 = tf.feature_column.numeric_column('x0')
x1 = tf.feature_column.numeric_column('x1')
y0 = tf.feature_column.numeric_column('y0')
y1 = tf.feature_column.numeric_column('y1')

numbuckets = 30
dx = np.linspace(-74.019108, -73.928684, numbuckets).tolist()
dy = np.linspace(40.700316, 40.877544, numbuckets).tolist()

x0_B = tf.feature_column.bucketized_column(x0, dx)
x1_B = tf.feature_column.bucketized_column(x1, dx)
y0_B = tf.feature_column.bucketized_column(y0, dy)
y1_B = tf.feature_column.bucketized_column(y1, dy)

xy_0 = tf.feature_column.crossed_column([x0_B, y0_B], numbuckets * numbuckets)
xy_1 = tf.feature_column.crossed_column([x1_B, y1_B], numbuckets * numbuckets)
xy_pair = tf.feature_column.crossed_column([xy_0, xy_1], numbuckets**4)

# definition of the categorical columns
hour = tf.feature_column.categorical_column_with_identity('hour', num_buckets = 24)
weekday = tf.feature_column.categorical_column_with_identity('weekday', num_buckets = 7)
week = tf.feature_column.categorical_column_with_identity('week', num_buckets = 54)
year = tf.feature_column.categorical_column_with_vocabulary_list('year', [2009, 2010, 2011, 2012, 2013, 2014, 2015])

loc_from = tf.feature_column.categorical_column_with_vocabulary_list('from', locations)
loc_to = tf.feature_column.categorical_column_with_vocabulary_list('to', locations)

# definition of the feature crosses
from_to = tf.feature_column.crossed_column([loc_from, loc_to], len(locations)**2)
from_to_year = tf.feature_column.crossed_column([from_to, year], len(locations)**2 * 7)
from_to_year_week = tf.feature_column.crossed_column([from_to_year, week], len(locations)**2 * 7 * 54)

weekday_year = tf.feature_column.crossed_column([weekday, year], 7 * 7)
hour_weekday_year = tf.feature_column.crossed_column([hour, weekday, year], 24 * 7 * 7)

deep_columns = [
    # Embedding_column to "group" together ...
    tf.feature_column.embedding_column(from_to, 50),
    tf.feature_column.embedding_column(from_to_year, 50),
    tf.feature_column.embedding_column(from_to_year_week, 50),
    tf.feature_column.embedding_column(weekday_year, 50),
    tf.feature_column.embedding_column(hour_weekday_year, 50),
    tf.feature_column.embedding_column(xy_pair, 50),

    # indicator columns
    tf.feature_column.indicator_column(loc_from),
    tf.feature_column.indicator_column(loc_to),
    tf.feature_column.indicator_column(hour),
    tf.feature_column.indicator_column(weekday),
    tf.feature_column.indicator_column(week),
    tf.feature_column.indicator_column(year),
    tf.feature_column.indicator_column(xy_0),
    tf.feature_column.indicator_column(xy_1),

    # numeric columns
    taxicab, euclidean, p_count
]

model_dir = './DNN_Regressor_regions_coords_overfit'

file_writer = tf.summary.FileWriter(model_dir)

estimator_other = tf.estimator.DNNRegressor(
    model_dir = model_dir,
    feature_columns = deep_columns,
    optimizer = tf.train.AdamOptimizer(learning_rate=0.0001),
    hidden_units = [128,128,128,128], 
    batch_norm = True,
)

generator = estimator_other.predict(input_fn=pred_input_fn(infer))
predictions = [next(generator) for i in range(len(infer))]
values = [val['predictions'].tolist()[0] for val in predictions]

ids = infer.index
submission_other = pd.DataFrame()
submission_other['fare_amount'] = values
submission_other['key'] = ids
submission_other.set_index('key', inplace=True)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './DNN_Regressor_regions_coords_overfit', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001F856272710>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_Regressor_regions_coords_overfit\model.ckpt-177188
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
other = infer[(infer['from'] != 'Manhattan') & (infer['to'] != 'Manhattan')].index

# %%
submission.loc[other,'fare_amount'] = submission_other.loc[other,'fare_amount']

# %%
submission.head()
# Out:
#                              fare_amount
# key
# 2015-01-27 13:08:24.0000002    10.159225
# 2015-01-27 13:08:24.0000003    11.004674
# 2011-10-08 11:53:44.0000002     4.678533
# 2012-12-01 21:12:12.0000002     8.184221
# 2012-12-01 21:12:12.0000003    17.117945

# %%
submission.to_csv('../output/20.dnn_regressor_manhattan_other_best_rmse_(2.43+3.01).csv')
