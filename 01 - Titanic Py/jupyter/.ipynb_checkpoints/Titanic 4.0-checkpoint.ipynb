# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)

# %%
train = pd.read_csv('../input/train.csv', index_col='PassengerId')
infer = pd.read_csv('../input/test.csv', index_col='PassengerId')

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
infer.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
full = pd.concat([train, infer])
# Out:
# C:\Users\vasil\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
full['Age'].fillna(-1, inplace=True)

# %%
train = full[full['Survived'].isnull() == False]
infer = full[full['Survived'].isnull() == True]

# %%
def split(df):
    from sklearn.model_selection import train_test_split
    
    X = df.drop('Survived', axis=1)
    y = df['Survived']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=379582)
    
    return pd.concat([X_train, y_train], axis=1), pd.concat([X_test, y_test],axis=1)

# %%
train, test = split(train)

# %%
import tensorflow as tf

# %%
# read feature columns from df
sex = tf.feature_column.categorical_column_with_vocabulary_list('Sex', vocabulary_list=['male', 'female'])
pclass = tf.feature_column.categorical_column_with_identity('Pclass', 4)
parch = tf.feature_column.categorical_column_with_identity('Parch', 10)
sibsp = tf.feature_column.categorical_column_with_identity('SibSp', 9)
age = tf.feature_column.numeric_column('Age')

# bucketizing age
age_b = tf.feature_column.bucketized_column(age,[0,7,12,18,30,36,44,55,65])

# defining feature crosses
parch_sib = tf.feature_column.crossed_column([parch,sibsp], 10 * 9)
age_class = tf.feature_column.crossed_column([age_b, pclass], 10 * 4)
age_sex = tf.feature_column.crossed_column([age_b, sex], 10 * 2)
sex_class = tf.feature_column.crossed_column([sex, pclass], 2 * 4)
parch_sib_age = tf.feature_column.crossed_column([parch,sibsp,age_b], 10 * 9 * 10)

# linear model
wide_columns = [
    sex, pclass, parch, sibsp,
    
    age_b,
    
    parch_sib, age_class, age_sex, sex_class, parch_sib_age
]

# neural network
deep_columns = [
    age_b,
    
    tf.feature_column.embedding_column(parch_sib, 5),
    tf.feature_column.embedding_column(age_class, 5),
    tf.feature_column.embedding_column(age_sex, 5),
    tf.feature_column.embedding_column(sex_class, 5),
    tf.feature_column.embedding_column(parch_sib_age, 10)
]

# %%
log = './DNN_CLASSIFIER'

config = tf.estimator.RunConfig(
    save_summary_steps=300, 
    save_checkpoints_secs=600, 
    keep_checkpoint_max=5, 
    log_step_count_steps=100, 
)

model = tf.estimator.DNNLinearCombinedClassifier(
    model_dir = log, 
    linear_feature_columns=wide_columns, 
    dnn_feature_columns=deep_columns, 
    dnn_hidden_units=[64,64,64,64], 
    n_classes=2, 
    dnn_dropout=0.2, 
    config=config, 
    dnn_optimizer=tf.train.AdamOptimizer(learning_rate=0.001)
)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './DNN_CLASSIFIER', '_tf_random_seed': None, '_save_summary_steps': 300, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000019FB9F03160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
def train_input_fn(df, batch_size):
    return tf.estimator.inputs.pandas_input_fn(
        x = df[['Sex', 'Pclass', 'Parch', 'SibSp', 'Age']],
        y = df['Survived'],
        num_epochs = 1,
        shuffle = True,
        batch_size = batch_size)

def eval_input_fn(df):
    return tf.estimator.inputs.pandas_input_fn(
        x = df[['Sex', 'Pclass', 'Parch', 'SibSp', 'Age']],
        y = df['Survived'],
        num_epochs = 1,
        shuffle = False)

def pred_input_fn(df):
    return tf.estimator.inputs.pandas_input_fn(
        x = df[['Sex', 'Pclass', 'Parch', 'SibSp', 'Age']],
        num_epochs = 1,
        shuffle = False)

# %%
train_spec = tf.estimator.TrainSpec(input_fn = train_input_fn(train, batch_size=256))
eval_spec = tf.estimator.EvalSpec(input_fn = eval_input_fn(test))

# %%
for i in range(0,100):
    tf.estimator.train_and_evaluate(model, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 176.42181, step = 0
# INFO:tensorflow:Saving checkpoints for 3 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:10:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-3
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:10:52
# INFO:tensorflow:Saving dict for global step 3: accuracy = 0.6135593, accuracy_baseline = 0.61355937, auc = 0.71958905, auc_precision_recall = 0.60816556, average_loss = 0.66231966, global_step = 3, label/mean = 0.38644066, loss = 65.128105, precision = 0.0, prediction/mean = 0.45026976, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3: ./DNN_CLASSIFIER\model.ckpt-3
# INFO:tensorflow:Loss for final step: 55.921967.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-3
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 170.14203, step = 3
# INFO:tensorflow:Saving checkpoints for 6 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:11:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-6
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:11:06
# INFO:tensorflow:Saving dict for global step 6: accuracy = 0.6135593, accuracy_baseline = 0.61355937, auc = 0.76390904, auc_precision_recall = 0.64842725, average_loss = 0.6461845, global_step = 6, label/mean = 0.38644066, loss = 63.541477, precision = 0.0, prediction/mean = 0.42194083, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6: ./DNN_CLASSIFIER\model.ckpt-6
# INFO:tensorflow:Loss for final step: 52.970303.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-6
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 164.75542, step = 6
# INFO:tensorflow:Saving checkpoints for 9 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:11:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-9
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:11:19
# INFO:tensorflow:Saving dict for global step 9: accuracy = 0.6135593, accuracy_baseline = 0.61355937, auc = 0.77476496, auc_precision_recall = 0.6592712, average_loss = 0.6328676, global_step = 9, label/mean = 0.38644066, loss = 62.23198, precision = 0.0, prediction/mean = 0.3956278, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9: ./DNN_CLASSIFIER\model.ckpt-9
# INFO:tensorflow:Loss for final step: 53.152584.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-9
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 159.15738, step = 9
# INFO:tensorflow:Saving checkpoints for 12 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:11:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-12
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:11:32
# INFO:tensorflow:Saving dict for global step 12: accuracy = 0.6135593, accuracy_baseline = 0.61355937, auc = 0.77420765, auc_precision_recall = 0.6597783, average_loss = 0.62131107, global_step = 12, label/mean = 0.38644066, loss = 61.095585, precision = 0.0, prediction/mean = 0.3739078, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12: ./DNN_CLASSIFIER\model.ckpt-12
# INFO:tensorflow:Loss for final step: 53.421516.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-12
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 12 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 152.68425, step = 12
# INFO:tensorflow:Saving checkpoints for 15 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:11:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-15
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:11:45
# INFO:tensorflow:Saving dict for global step 15: accuracy = 0.6135593, accuracy_baseline = 0.61355937, auc = 0.77382, auc_precision_recall = 0.66055864, average_loss = 0.61134535, global_step = 15, label/mean = 0.38644066, loss = 60.115627, precision = 0.0, prediction/mean = 0.3599687, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15: ./DNN_CLASSIFIER\model.ckpt-15
# INFO:tensorflow:Loss for final step: 51.443764.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-15
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 153.99443, step = 15
# INFO:tensorflow:Saving checkpoints for 18 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:11:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-18
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:11:58
# INFO:tensorflow:Saving dict for global step 18: accuracy = 0.62711865, accuracy_baseline = 0.61355937, auc = 0.77825433, auc_precision_recall = 0.66963017, average_loss = 0.6012303, global_step = 18, label/mean = 0.38644066, loss = 59.120983, precision = 0.8333333, prediction/mean = 0.35457572, recall = 0.04385965
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18: ./DNN_CLASSIFIER\model.ckpt-18
# INFO:tensorflow:Loss for final step: 50.246056.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-18
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 18 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 149.96156, step = 18
# INFO:tensorflow:Saving checkpoints for 21 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:12:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-21
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:12:11
# INFO:tensorflow:Saving dict for global step 21: accuracy = 0.65084743, accuracy_baseline = 0.61355937, auc = 0.7830522, auc_precision_recall = 0.6784584, average_loss = 0.5907499, global_step = 21, label/mean = 0.38644066, loss = 58.09041, precision = 0.7894737, prediction/mean = 0.3540881, recall = 0.13157895
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 21: ./DNN_CLASSIFIER\model.ckpt-21
# INFO:tensorflow:Loss for final step: 44.958008.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-21
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 21 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 150.85004, step = 21
# INFO:tensorflow:Saving checkpoints for 24 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:12:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-24
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:12:25
# INFO:tensorflow:Saving dict for global step 24: accuracy = 0.6677966, accuracy_baseline = 0.61355937, auc = 0.7861781, auc_precision_recall = 0.69633, average_loss = 0.58022314, global_step = 24, label/mean = 0.38644066, loss = 57.05528, precision = 0.7222222, prediction/mean = 0.35499805, recall = 0.22807017
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24: ./DNN_CLASSIFIER\model.ckpt-24
# INFO:tensorflow:Loss for final step: 47.361534.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-24
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 152.74802, step = 24
# INFO:tensorflow:Saving checkpoints for 27 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:12:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-27
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:12:37
# INFO:tensorflow:Saving dict for global step 27: accuracy = 0.6847458, accuracy_baseline = 0.61355937, auc = 0.7867354, auc_precision_recall = 0.7039363, average_loss = 0.5701614, global_step = 27, label/mean = 0.38644066, loss = 56.065872, precision = 0.73333335, prediction/mean = 0.3585292, recall = 0.28947368
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 27: ./DNN_CLASSIFIER\model.ckpt-27
# INFO:tensorflow:Loss for final step: 47.804928.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-27
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 27 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 141.01073, step = 27
# INFO:tensorflow:Saving checkpoints for 30 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:12:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:12:51
# INFO:tensorflow:Saving dict for global step 30: accuracy = 0.6983051, accuracy_baseline = 0.61355937, auc = 0.7885044, auc_precision_recall = 0.70812047, average_loss = 0.5607722, global_step = 30, label/mean = 0.38644066, loss = 55.142597, precision = 0.7118644, prediction/mean = 0.36148787, recall = 0.36842105
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30: ./DNN_CLASSIFIER\model.ckpt-30
# INFO:tensorflow:Loss for final step: 51.168842.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 30 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 146.2404, step = 30
# INFO:tensorflow:Saving checkpoints for 33 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:13:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-33
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:13:04
# INFO:tensorflow:Saving dict for global step 33: accuracy = 0.7288136, accuracy_baseline = 0.61355937, auc = 0.7927934, auc_precision_recall = 0.71548104, average_loss = 0.55162174, global_step = 33, label/mean = 0.38644066, loss = 54.2428, precision = 0.6976744, prediction/mean = 0.36521617, recall = 0.5263158
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 33: ./DNN_CLASSIFIER\model.ckpt-33
# INFO:tensorflow:Loss for final step: 46.87799.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-33
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 33 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 132.84296, step = 33
# INFO:tensorflow:Saving checkpoints for 36 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:13:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-36
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:13:18
# INFO:tensorflow:Saving dict for global step 36: accuracy = 0.74915254, accuracy_baseline = 0.61355937, auc = 0.795774, auc_precision_recall = 0.7207238, average_loss = 0.5427149, global_step = 36, label/mean = 0.38644066, loss = 53.366962, precision = 0.6851852, prediction/mean = 0.36705118, recall = 0.64912283
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 36: ./DNN_CLASSIFIER\model.ckpt-36
# INFO:tensorflow:Loss for final step: 42.41906.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-36
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 36 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 129.40561, step = 36
# INFO:tensorflow:Saving checkpoints for 39 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:13:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-39
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:13:31
# INFO:tensorflow:Saving dict for global step 39: accuracy = 0.7559322, accuracy_baseline = 0.61355937, auc = 0.8000873, auc_precision_recall = 0.7253736, average_loss = 0.53485125, global_step = 39, label/mean = 0.38644066, loss = 52.593704, precision = 0.68421054, prediction/mean = 0.36798334, recall = 0.68421054
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39: ./DNN_CLASSIFIER\model.ckpt-39
# INFO:tensorflow:Loss for final step: 41.940357.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-39
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 39 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 136.68115, step = 39
# INFO:tensorflow:Saving checkpoints for 42 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:13:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-42
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:13:44
# INFO:tensorflow:Saving dict for global step 42: accuracy = 0.7525424, accuracy_baseline = 0.61355937, auc = 0.80146843, auc_precision_recall = 0.72358674, average_loss = 0.5275532, global_step = 42, label/mean = 0.38644066, loss = 51.876064, precision = 0.6666667, prediction/mean = 0.36976033, recall = 0.71929824
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 42: ./DNN_CLASSIFIER\model.ckpt-42
# INFO:tensorflow:Loss for final step: 38.5824.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-42
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 42 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 142.21327, step = 42
# INFO:tensorflow:Saving checkpoints for 45 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:13:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-45
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:13:58
# INFO:tensorflow:Saving dict for global step 45: accuracy = 0.74915254, accuracy_baseline = 0.61355937, auc = 0.80684793, auc_precision_recall = 0.73007905, average_loss = 0.52093184, global_step = 45, label/mean = 0.38644066, loss = 51.224964, precision = 0.66129035, prediction/mean = 0.37175232, recall = 0.71929824
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45: ./DNN_CLASSIFIER\model.ckpt-45
# INFO:tensorflow:Loss for final step: 36.30012.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-45
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 45 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 124.939575, step = 45
# INFO:tensorflow:Saving checkpoints for 48 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:14:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:14:13
# INFO:tensorflow:Saving dict for global step 48: accuracy = 0.7525424, accuracy_baseline = 0.61355937, auc = 0.8091499, auc_precision_recall = 0.73006487, average_loss = 0.51638347, global_step = 48, label/mean = 0.38644066, loss = 50.77771, precision = 0.6614173, prediction/mean = 0.36969915, recall = 0.7368421
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48: ./DNN_CLASSIFIER\model.ckpt-48
# INFO:tensorflow:Loss for final step: 50.0491.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 48 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 120.98091, step = 48
# INFO:tensorflow:Saving checkpoints for 51 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:14:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-51
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:14:26
# INFO:tensorflow:Saving dict for global step 51: accuracy = 0.7627119, accuracy_baseline = 0.61355937, auc = 0.81164575, auc_precision_recall = 0.73281854, average_loss = 0.51121205, global_step = 51, label/mean = 0.38644066, loss = 50.269184, precision = 0.66923076, prediction/mean = 0.3761206, recall = 0.7631579
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 51: ./DNN_CLASSIFIER\model.ckpt-51
# INFO:tensorflow:Loss for final step: 45.89751.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-51
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 51 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 129.20244, step = 51
# INFO:tensorflow:Saving checkpoints for 54 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:14:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-54
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:14:41
# INFO:tensorflow:Saving dict for global step 54: accuracy = 0.78305084, accuracy_baseline = 0.61355937, auc = 0.81588644, auc_precision_recall = 0.7422288, average_loss = 0.50587875, global_step = 54, label/mean = 0.38644066, loss = 49.74474, precision = 0.6785714, prediction/mean = 0.38860437, recall = 0.8333333
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 54: ./DNN_CLASSIFIER\model.ckpt-54
# INFO:tensorflow:Loss for final step: 37.216763.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-54
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 54 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 126.396996, step = 54
# INFO:tensorflow:Saving checkpoints for 57 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:14:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-57
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:14:55
# INFO:tensorflow:Saving dict for global step 57: accuracy = 0.7728813, accuracy_baseline = 0.61355937, auc = 0.82063586, auc_precision_recall = 0.74962854, average_loss = 0.50141674, global_step = 57, label/mean = 0.38644066, loss = 49.30598, precision = 0.66433567, prediction/mean = 0.39607105, recall = 0.8333333
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 57: ./DNN_CLASSIFIER\model.ckpt-57
# INFO:tensorflow:Loss for final step: 37.405647.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-57
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 57 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 119.19635, step = 57
# INFO:tensorflow:Saving checkpoints for 60 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:15:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:15:08
# INFO:tensorflow:Saving dict for global step 60: accuracy = 0.76949155, accuracy_baseline = 0.61355937, auc = 0.8241979, auc_precision_recall = 0.755332, average_loss = 0.49665642, global_step = 60, label/mean = 0.38644066, loss = 48.83788, precision = 0.6597222, prediction/mean = 0.40300533, recall = 0.8333333
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 60: ./DNN_CLASSIFIER\model.ckpt-60
# INFO:tensorflow:Loss for final step: 37.739193.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 60 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 122.405426, step = 60
# INFO:tensorflow:Saving checkpoints for 63 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:15:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-63
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:15:21
# INFO:tensorflow:Saving dict for global step 63: accuracy = 0.7728813, accuracy_baseline = 0.61355937, auc = 0.8366288, auc_precision_recall = 0.77069557, average_loss = 0.49249133, global_step = 63, label/mean = 0.38644066, loss = 48.428314, precision = 0.66433567, prediction/mean = 0.40108484, recall = 0.8333333
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 63: ./DNN_CLASSIFIER\model.ckpt-63
# INFO:tensorflow:Loss for final step: 45.175964.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-63
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 63 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 109.75904, step = 63
# INFO:tensorflow:Saving checkpoints for 66 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:15:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:15:34
# INFO:tensorflow:Saving dict for global step 66: accuracy = 0.7728813, accuracy_baseline = 0.61355937, auc = 0.8378405, auc_precision_recall = 0.7743355, average_loss = 0.48826703, global_step = 66, label/mean = 0.38644066, loss = 48.012924, precision = 0.6666667, prediction/mean = 0.3914244, recall = 0.8245614
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 66: ./DNN_CLASSIFIER\model.ckpt-66
# INFO:tensorflow:Loss for final step: 46.643375.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 66 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 109.12028, step = 66
# INFO:tensorflow:Saving checkpoints for 69 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:15:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-69
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:15:48
# INFO:tensorflow:Saving dict for global step 69: accuracy = 0.77627116, accuracy_baseline = 0.61355937, auc = 0.83754975, auc_precision_recall = 0.77842605, average_loss = 0.48495358, global_step = 69, label/mean = 0.38644066, loss = 47.687103, precision = 0.67142856, prediction/mean = 0.38775036, recall = 0.8245614
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 69: ./DNN_CLASSIFIER\model.ckpt-69
# INFO:tensorflow:Loss for final step: 49.590523.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-69
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 69 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 126.31104, step = 69
# INFO:tensorflow:Saving checkpoints for 72 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:15:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:16:01
# INFO:tensorflow:Saving dict for global step 72: accuracy = 0.7728813, accuracy_baseline = 0.61355937, auc = 0.8378405, auc_precision_recall = 0.78276104, average_loss = 0.48142943, global_step = 72, label/mean = 0.38644066, loss = 47.34056, precision = 0.6766917, prediction/mean = 0.3941202, recall = 0.7894737
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 72: ./DNN_CLASSIFIER\model.ckpt-72
# INFO:tensorflow:Loss for final step: 38.39249.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 72 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 115.43303, step = 72
# INFO:tensorflow:Saving checkpoints for 75 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:16:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-75
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:16:14
# INFO:tensorflow:Saving dict for global step 75: accuracy = 0.77627116, accuracy_baseline = 0.61355937, auc = 0.8429776, auc_precision_recall = 0.7901033, average_loss = 0.4782779, global_step = 75, label/mean = 0.38644066, loss = 47.03066, precision = 0.6818182, prediction/mean = 0.39727902, recall = 0.7894737
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 75: ./DNN_CLASSIFIER\model.ckpt-75
# INFO:tensorflow:Loss for final step: 42.458977.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-75
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 75 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 102.79978, step = 75
# ...
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:30:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-276
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:30:26
# INFO:tensorflow:Saving dict for global step 276: accuracy = 0.7864407, accuracy_baseline = 0.61355937, auc = 0.84019095, auc_precision_recall = 0.80710113, average_loss = 0.52188, global_step = 276, label/mean = 0.38644066, loss = 51.318195, precision = 0.7297297, prediction/mean = 0.40384418, recall = 0.7105263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 276: ./DNN_CLASSIFIER\model.ckpt-276
# INFO:tensorflow:Loss for final step: 22.735874.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-276
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 276 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 88.745155, step = 276
# INFO:tensorflow:Saving checkpoints for 279 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:30:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-279
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:30:39
# INFO:tensorflow:Saving dict for global step 279: accuracy = 0.7864407, accuracy_baseline = 0.61355937, auc = 0.84048176, auc_precision_recall = 0.81042504, average_loss = 0.5189785, global_step = 279, label/mean = 0.38644066, loss = 51.032883, precision = 0.7297297, prediction/mean = 0.40327644, recall = 0.7105263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 279: ./DNN_CLASSIFIER\model.ckpt-279
# INFO:tensorflow:Loss for final step: 22.69069.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-279
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 279 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 78.38096, step = 279
# INFO:tensorflow:Saving checkpoints for 282 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:30:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-282
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:30:51
# INFO:tensorflow:Saving dict for global step 282: accuracy = 0.7898305, accuracy_baseline = 0.61355937, auc = 0.8405786, auc_precision_recall = 0.81103957, average_loss = 0.51841676, global_step = 282, label/mean = 0.38644066, loss = 50.977646, precision = 0.73636365, prediction/mean = 0.4001865, recall = 0.7105263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 282: ./DNN_CLASSIFIER\model.ckpt-282
# INFO:tensorflow:Loss for final step: 30.16422.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-282
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 282 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 83.29823, step = 282
# INFO:tensorflow:Saving checkpoints for 285 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:31:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-285
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:31:03
# INFO:tensorflow:Saving dict for global step 285: accuracy = 0.7966102, accuracy_baseline = 0.61355937, auc = 0.8416449, auc_precision_recall = 0.81147027, average_loss = 0.5186842, global_step = 285, label/mean = 0.38644066, loss = 51.00395, precision = 0.754717, prediction/mean = 0.39492455, recall = 0.7017544
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 285: ./DNN_CLASSIFIER\model.ckpt-285
# INFO:tensorflow:Loss for final step: 32.823315.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-285
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 285 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 79.19769, step = 285
# INFO:tensorflow:Saving checkpoints for 288 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:31:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-288
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:31:21
# INFO:tensorflow:Saving dict for global step 288: accuracy = 0.8, accuracy_baseline = 0.61355937, auc = 0.84019095, auc_precision_recall = 0.8102329, average_loss = 0.5234399, global_step = 288, label/mean = 0.38644066, loss = 51.47159, precision = 0.7619048, prediction/mean = 0.39625874, recall = 0.7017544
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 288: ./DNN_CLASSIFIER\model.ckpt-288
# INFO:tensorflow:Loss for final step: 24.797104.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-288
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 288 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 81.42233, step = 288
# INFO:tensorflow:Saving checkpoints for 291 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:31:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-291
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:31:33
# INFO:tensorflow:Saving dict for global step 291: accuracy = 0.8, accuracy_baseline = 0.61355937, auc = 0.83924586, auc_precision_recall = 0.8088913, average_loss = 0.52766776, global_step = 291, label/mean = 0.38644066, loss = 51.88733, precision = 0.7619048, prediction/mean = 0.40036586, recall = 0.7017544
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 291: ./DNN_CLASSIFIER\model.ckpt-291
# INFO:tensorflow:Loss for final step: 33.38716.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-291
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 291 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 79.17242, step = 291
# INFO:tensorflow:Saving checkpoints for 294 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:31:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-294
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:31:45
# INFO:tensorflow:Saving dict for global step 294: accuracy = 0.79322034, accuracy_baseline = 0.61355937, auc = 0.8393185, auc_precision_recall = 0.8087323, average_loss = 0.5312163, global_step = 294, label/mean = 0.38644066, loss = 52.23627, precision = 0.74311924, prediction/mean = 0.40121844, recall = 0.7105263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 294: ./DNN_CLASSIFIER\model.ckpt-294
# INFO:tensorflow:Loss for final step: 29.946922.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-294
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 294 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 79.57826, step = 294
# INFO:tensorflow:Saving checkpoints for 297 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:31:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-297
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:31:57
# INFO:tensorflow:Saving dict for global step 297: accuracy = 0.7898305, accuracy_baseline = 0.61355937, auc = 0.838834, auc_precision_recall = 0.8106264, average_loss = 0.5369029, global_step = 297, label/mean = 0.38644066, loss = 52.795452, precision = 0.73214287, prediction/mean = 0.4055493, recall = 0.71929824
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 297: ./DNN_CLASSIFIER\model.ckpt-297
# INFO:tensorflow:Loss for final step: 28.271809.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-297
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 297 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:loss = 78.47453, step = 297
# INFO:tensorflow:Saving checkpoints for 300 into ./DNN_CLASSIFIER\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-16-15:32:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER\model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-16-15:32:09
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.78305084, accuracy_baseline = 0.61355937, auc = 0.8379374, auc_precision_recall = 0.8084254, average_loss = 0.54157126, global_step = 300, label/mean = 0.38644066, loss = 53.254505, precision = 0.7155172, prediction/mean = 0.4077936, recall = 0.7280702
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 300: ./DNN_CLASSIFIER\model.ckpt-300
# INFO:tensorflow:Loss for final step: 26.374126.

# %%
generator = model.predict(input_fn=pred_input_fn(infer), checkpoint_path='./DNN_CLASSIFIER/model.ckpt-288')

# %%
predictions = [next(generator) for i in range(len(infer))]
values = [val['class_ids'].tolist()[0] for val in predictions]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./DNN_CLASSIFIER/model.ckpt-288
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
submission = pd.DataFrame()

submission['PassengerId'] = infer.index
submission['Survived'] = values

submission.to_csv('../output/DNN_Linear_Combined_Classifier_V3.csv', index=False)
