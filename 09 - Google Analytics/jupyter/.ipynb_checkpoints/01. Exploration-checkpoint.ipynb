# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)

# %%
dtypes = {
    'channelGrouping' : str,
    'date' : str,
    'device' : str,
    'fullVisitorId' : str,
    'geoNetwork' : str,
    'sessionId' : str,
    'socialEngagementType' : str,
    'totals' : str,
    'trafficSource' : str,
    'visitId' : np.int64,
    'visitNumber' : np.int16,
    'visitStartTime' : np.int64
}

# %%
train = pd.read_csv('../input/train.csv', dtype=dtypes, parse_dates=['date'])

# %%
def data_engineering(df):
    
    def get_keys(series):
        keys = set()
        for element in series:
            keys = keys.union(set(element.keys()))
            
        return keys
    
    def get_value(d, key):
        if key in d:
            try:
                return eval(d[key])
            except:
                return d[key]
        else:
            return np.nan
    
    df['device'] = df['device'].transform(lambda x: eval(x))
    df['totals'] = df['totals'].transform(lambda x: eval(x))
    df['geoNetwork'] = df['geoNetwork'].transform(lambda x: eval(x))
    df['trafficSource'] = df['trafficSource'].transform(lambda x: eval(x))
    df['visitStartTime'] = pd.to_datetime(df['visitStartTime'], unit='s')
    
    keys = get_keys(df['geoNetwork'])
    for key in keys:
        df['g_'+key] = df['geoNetwork'].transform(lambda x: get_value(x, key))
        
    keys = get_keys(df['totals'])
    for key in keys:
        if key == 'transactionRevenue':
            df['target'] = df['totals'].transform(lambda x: get_value(x, key))
        else:
            df['t_'+key] = df['totals'].transform(lambda x: get_value(x, key))
        
    keys = get_keys(df['trafficSource'])
    for key in keys:
        df['ts_'+key] = df['trafficSource'].transform(lambda x: get_value(x, key))
        
    keys = get_keys(df['device'])
    for key in keys:
        df['d_'+key] = df['device'].transform(lambda x: get_value(x, key))
    
    df.drop(['totals', 'trafficSource', 'device', 'geoNetwork'], axis=1, inplace=True)
    
    # all levels are equal
    df.drop([
             'g_cityId', 'g_networkLocation', 'g_latitude', 'g_longitude', 't_visits',
             'ts_adwordsClickInfo', 'd_mobileDeviceInfo', 'd_mobileDeviceModel', 'd_language',
             'd_flashVersion', 'd_browserVersion', 'd_mobileDeviceBranding', 'd_mobileInputSelector',
             'd_mobileDeviceMarketingName', 'd_operatingSystemVersion', 'd_screenResolution', 'd_screenColors',
             'd_browserSize'
            ], axis=1, inplace=True)
    
    for column in df.columns:
        df[column] = df[column].replace('(none)', np.nan)
        df[column] = df[column].replace(False, np.nan)
        df[column] = df[column].replace('not available in demo dataset', np.nan)
        df[column] = df[column].replace('(not provided)', np.nan)
        
    df.loc[:,'target_bool'] = 0
    df.loc[df['target'] > 0,'target_bool'] = 1
    
    df['month'] = df['date'].dt.month
    df['weekday'] = df['date'].dt.dayofweek

# %%
true, false = True, False
data_engineering(train)

# %%
train[train['g_continent'].isna()]
# Out:
#        channelGrouping       date        fullVisitorId  \
# 310           Referral 2016-09-02   149633083723377298
# 1312            Social 2016-09-02  0983912688516501789
# 1784    Organic Search 2016-09-02  9660655671713860097
# 1788    Organic Search 2016-09-02  4213667415448778925
# 2125            Social 2016-09-02  4696756425353528990
# 2138            Social 2016-09-02  8682450913674241936
# 3203        Affiliates 2017-01-26   000696790665307308
# 3584            Social 2017-01-26  5076747184606670106
# 4270        Affiliates 2017-01-26   000696790665307308
# 8608            Social 2017-03-12  9768709211110843370
# 898659            1 2017-05-31 11:01:49      5        2     ...
# 899912            1 2017-07-09 13:35:33      7        6     ...
# 900137            1 2017-07-09 15:05:42      7        6     ...
# 901303            1 2017-01-05 02:23:41      1        2     ...
# 901330            1 2017-01-04 14:02:49      1        2     ...
# 902258            3 2017-01-05 04:40:16      1        2     ...
# 902710            2 2017-01-05 03:13:37      1        2     ...
# 902979            4 2017-01-05 07:00:22      1        2     ...
# 903097            1 2017-01-04 23:08:41      1        2     ...
#
#          ts_keyword ts_isTrueDirect ts_campaignCode  \
# 310             NaN             NaN             NaN
# 1312            NaN             NaN             NaN
# 1784            NaN             NaN             NaN
# 1788            NaN             NaN             NaN
# 2125            NaN             NaN             NaN
# 2138            NaN             NaN             NaN
# 3203            NaN            True             NaN
# 3584            NaN             NaN             NaN
# 4270            NaN             NaN             NaN
# 8608            NaN             NaN             NaN
# 8907            NaN             NaN             NaN
# 9538            NaN             NaN             NaN
# 9640            NaN             NaN             NaN
# 10890           NaN             NaN             NaN
# 11961           NaN             NaN             NaN
# 12053           NaN             NaN             NaN
# 12365           NaN            True             NaN
# 12647           NaN            True             NaN
# 13620           NaN             NaN             NaN
# 14726           NaN             NaN             NaN
# 15285           NaN             NaN             NaN
# 15654       youtube             NaN             NaN
# 16336           NaN             NaN             NaN
# 16398           NaN            True             NaN
# 19538           NaN             NaN             NaN
# 22287           NaN             NaN             NaN
# 24036           NaN             NaN             NaN
# 25419           NaN             NaN             NaN
# 26541           NaN             NaN             NaN
# 28105           NaN             NaN             NaN
# ...             ...             ...             ...
# 880159          NaN             NaN             NaN
# 883330          NaN             NaN             NaN
# 883819          NaN             NaN             NaN
# 883909          NaN             NaN             NaN
# 884799          NaN            True             NaN
# 884917          NaN            True             NaN
# 885197          NaN             NaN             NaN
# 887062          NaN             NaN             NaN
# 887171          NaN             NaN             NaN
# 887389          NaN             NaN             NaN
# 888786          NaN             NaN             NaN
# 889360          NaN             NaN             NaN
# 889383          NaN             NaN             NaN
# 893370          NaN            True             NaN
# 893445          NaN            True             NaN
# 893564          NaN            True             NaN
# 893681          NaN            True             NaN
# 893894  googlestore             NaN             NaN
# 894716          NaN            True             NaN
# 896693          NaN             NaN             NaN
# 898604          NaN             NaN             NaN
# 898659          NaN             NaN             NaN
# 899912          NaN             NaN             NaN
# 900137          NaN             NaN             NaN
# 901303          NaN             NaN             NaN
# 901330          NaN             NaN             NaN
# 902258          NaN            True             NaN
# 902710          NaN            True             NaN
# 902979          NaN            True             NaN
# 903097          NaN             NaN             NaN
#
#                              ts_referralPath             ts_source  \
# 310                          /analytics/web/  analytics.google.com
# 1312                        /yt/about/en-GB/           youtube.com
# 1784                                     NaN                google
# 1788                                     NaN                google
# 2125                              /yt/about/           youtube.com
# 2138                              /yt/about/           youtube.com
# 3203                                     NaN              Partners
# 3584                        /yt/about/zh-CN/           youtube.com
# 4270                                     NaN              Partners
# 8608                              /yt/about/           youtube.com
# 8907                                     NaN                 baidu
# 9538                                     NaN                google
# 9640                                     NaN                google
# 10890                                    NaN                google
# 11961                             /yt/about/           youtube.com
# 12053                             /yt/about/           youtube.com
# 12365                                    NaN              (direct)
# 12647                                    NaN              (direct)
# 13620                                    NaN                google
# 14726   /YKEI_mrn/items/c10b14f9a69ff71b1b7a             qiita.com
# 15285                                    NaN                google
# 15654                                    NaN                google
# 16336                                    NaN                google
# 16398                                    NaN                google
# 19538                                    NaN                google
# 22287                                    NaN                google
# 24036                          /yt/about/tr/           youtube.com
# 25419                          /yt/about/tr/           youtube.com
# 26541                       /yt/about/en-GB/           youtube.com
# 28105                                    NaN                google
# ...                                      ...                   ...
# 880159                                   NaN                google
# 883330                                   NaN                 baidu
# 883819                            /yt/about/           youtube.com
# 883909                                   NaN                google
# 884799                                   NaN              (direct)
# 884917                                   NaN              (direct)
# 885197                                   NaN                google
# 887062                 /intl/en-GB/yt/about/           youtube.com
# 887171                                   NaN                 baidu
# 887389                                   NaN                google
# 888786                                   NaN                google
# 889360                            /yt/about/           youtube.com
# 889383                            /yt/about/           youtube.com
# 893370                                   NaN              (direct)
# 893445                                   NaN              (direct)
# 893564                                   NaN              (direct)
# 893681                                   NaN              (direct)
# 893894                                   NaN                 baidu
# 894716                                   NaN              (direct)
# 896693                                   NaN                google
# 898604                                   NaN                google
# 898659                                   NaN                google
# 899912                                   NaN                google
# 900137                                   NaN                google
# 901303                                   NaN                google
# 901330                                   NaN                google
# 902258                                   NaN                google
# 902710                                   NaN                google
# 902979                                   NaN                google
# 903097                                   NaN                google
#
#        d_deviceCategory d_operatingSystem   d_browser  d_isMobile  target_bool
# 310             desktop           Windows      Chrome         NaN            0
# 1312             mobile               NaN  Opera Mini         1.0            0
# 1784            desktop           Windows     Firefox         NaN            0
# 1788            desktop           Windows      Chrome         NaN            0
# 2125            desktop           Windows       Opera         NaN            0
# 2138            desktop           Windows      Chrome         NaN            0
# 3203            desktop             Linux      Chrome         NaN            0
# 3584            desktop         Macintosh      Safari         NaN            0
# 4270            desktop             Linux      Chrome         NaN            0
# 8608            desktop           Windows      Chrome         NaN            0
# 8907             mobile               iOS      Safari         1.0            0
# 9538            desktop           Windows      Chrome         NaN            0
# 9640            desktop           Windows     Firefox         NaN            0
# 10890           desktop           Windows      Chrome         NaN            0
# 11961            mobile           Android  Opera Mini         1.0            0
# 12053            mobile               NaN  Opera Mini         1.0            0
# 12365           desktop           Windows     Firefox         NaN            0
# 12647            mobile               NaN  Opera Mini         1.0            0
# 13620            mobile           Android      Chrome         1.0            0
# 14726           desktop           Windows      Chrome         NaN            0
# 15285            mobile           Android      Chrome         1.0            0
# 15654            mobile               NaN  Opera Mini         1.0            0
# 16336           desktop           Windows     Firefox         NaN            0
# 16398           desktop         Macintosh      Chrome         NaN            0
# 19538           desktop           Windows      Chrome         NaN            0
# 22287           desktop           Windows      Chrome         NaN            0
# 24036           desktop           Windows      Chrome         NaN            0
# 25419           desktop           Windows      Chrome         NaN            0
# 26541           desktop           Windows      Chrome         NaN            0
# 28105           desktop           Windows      Chrome         NaN            0
# ...                 ...               ...         ...         ...          ...
# 880159          desktop           Windows      Chrome         NaN            0
# 883330          desktop           Windows     Maxthon         NaN            0
# 883819          desktop           Windows      Chrome         NaN            0
# 883909          desktop           Windows      Chrome         NaN            0
# 884799          desktop               NaN      Chrome         NaN            0
# 884917          desktop               NaN      Chrome         NaN            0
# 885197          desktop           Windows      Chrome         NaN            0
# 887062          desktop         Macintosh      Safari         NaN            0
# 887171          desktop           Windows      Chrome         NaN            0
# 887389           mobile           Android      Chrome         1.0            0
# 888786          desktop           Windows      Chrome         NaN            0
# 889360          desktop           Windows       Opera         NaN            0
# 889383          desktop           Windows      Chrome         NaN            0
# 893370          desktop             Linux      Chrome         NaN            0
# 893445          desktop             Linux      Chrome         NaN            0
# 893564          desktop             Linux      Chrome         NaN            0
# 893681          desktop             Linux      Chrome         NaN            0
# 893894           mobile           Android  UC Browser         1.0            0
# 894716           mobile           Android      Chrome         1.0            0
# 896693           mobile           Android      Chrome         1.0            0
# 898604          desktop           Windows      Chrome         NaN            0
# 898659          desktop         Macintosh      Chrome         NaN            0
# 899912           mobile           Android      Chrome         1.0            0
# 900137          desktop           Windows      Chrome         NaN            0
# 901303          desktop           Windows      Chrome         NaN            0
# 901330          desktop           Windows      Chrome         NaN            0
# 902258          desktop           Windows      Chrome         NaN            0
# 902710          desktop           Windows      Chrome         NaN            0
# 902979          desktop           Windows      Chrome         NaN            0
# 903097           mobile               iOS  UC Browser         1.0            0
#
# [1468 rows x 35 columns]

# %%
train.isna().sum()
# Out:
# channelGrouping              0
# date                         0
# fullVisitorId                0
# sessionId                    0
# socialEngagementType         0
# visitId                      0
# visitNumber                  0
# visitStartTime               0
# month                        0
# weekday                      0
# g_networkDomain         244881
# g_city                  542491
# g_country                 1468
# g_continent               1468
# g_region                536056
# g_metro                 709995
# g_subContinent            1468
# t_newVisits             200593
# target                  892138
# t_pageviews                100
# t_hits                       0
# t_bounces               453023
# ts_adContent            892707
# ts_medium               143146
# ts_campaign             865347
# ts_keyword              869292
# ts_isTrueDirect         629648
# ts_campaignCode         903652
# ts_referralPath         572712
# ts_source                   69
# d_deviceCategory             0
# d_operatingSystem         4695
# d_browser                   15
# d_isMobile              664530
# target_bool                  0
# dtype: int64

# %%
def aggregate_df(df):
    
    def most_common(lst):
        return max(set(lst), key=lst.count)
    
    agg = pd.DataFrame(data=df['fullVisitorId'].unique(), columns=['fullVisitorId'])
    
    agg = pd.merge(
            agg, 
            np.log1p(df.groupby('fullVisitorId')['target'].sum()).to_frame(), 
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    agg = pd.merge(
            agg, 
            df.groupby('fullVisitorId')['sessionId'].count().to_frame(), 
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    agg = pd.merge(
            agg, 
            df.groupby('fullVisitorId')['target_bool'].sum().to_frame(), 
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    agg = pd.merge(
            agg,
            df.groupby('fullVisitorId')['g_country'].apply(lambda x: most_common(x.values.tolist())).to_frame(),
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    train.groupby('fullVisitorId')['g_country'].apply(lambda x: most_common(x.values.tolist()))
    
    agg.columns = ['fullVisitorId', 'target', 'num_sess', 'num_deals', 'country']
    
    return agg
