# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)

# %%
dtypes = {
    'channelGrouping' : str,
    'date' : str,
    'device' : str,
    'fullVisitorId' : str,
    'geoNetwork' : str,
    'sessionId' : str,
    'socialEngagementType' : str,
    'totals' : str,
    'trafficSource' : str,
    'visitId' : np.int64,
    'visitNumber' : np.int16,
    'visitStartTime' : np.int64
}

# %%
train = pd.read_csv('../input/train.csv', dtype=dtypes, parse_dates=['date'])

# %%
def data_engineering(df):
    
    def get_keys(series):
        keys = set()
        for element in series:
            keys = keys.union(set(element.keys()))
            
        return keys
    
    def get_value(d, key):
        if key in d:
            try:
                return eval(d[key])
            except:
                return d[key]
        else:
            return np.nan
    
    df['device'] = df['device'].transform(lambda x: eval(x))
    df['totals'] = df['totals'].transform(lambda x: eval(x))
    df['geoNetwork'] = df['geoNetwork'].transform(lambda x: eval(x))
    df['trafficSource'] = df['trafficSource'].transform(lambda x: eval(x))
    df['visitStartTime'] = pd.to_datetime(df['visitStartTime'], unit='s')
    
    keys = get_keys(df['geoNetwork'])
    for key in keys:
        df['g_'+key] = df['geoNetwork'].transform(lambda x: get_value(x, key))
        
    keys = get_keys(df['totals'])
    for key in keys:
        if key == 'transactionRevenue':
            df['target'] = df['totals'].transform(lambda x: get_value(x, key))
        else:
            df['t_'+key] = df['totals'].transform(lambda x: get_value(x, key))
        
    keys = get_keys(df['trafficSource'])
    for key in keys:
        df['ts_'+key] = df['trafficSource'].transform(lambda x: get_value(x, key))
        
    keys = get_keys(df['device'])
    for key in keys:
        df['d_'+key] = df['device'].transform(lambda x: get_value(x, key))
    
    df.drop(['totals', 'trafficSource', 'device', 'geoNetwork'], axis=1, inplace=True)
    
    # all levels are equal
    df.drop([
             'g_cityId', 'g_networkLocation', 'g_latitude', 'g_longitude', 't_visits',
             'ts_adwordsClickInfo', 'd_mobileDeviceInfo', 'd_mobileDeviceModel', 'd_language',
             'd_flashVersion', 'd_browserVersion', 'd_mobileDeviceBranding', 'd_mobileInputSelector',
             'd_mobileDeviceMarketingName', 'd_operatingSystemVersion', 'd_screenResolution', 'd_screenColors',
             'd_browserSize', 'ts_campaignCode'
            ], axis=1, inplace=True)
    
    for column in df.columns:
        df[column] = df[column].replace('(none)', np.nan)
        df[column] = df[column].replace('not available in demo dataset', np.nan)
        df[column] = df[column].replace('(not provided)', np.nan)
        
    df.loc[:,'target_bool'] = 0
    df.loc[df['target'] > 0,'target_bool'] = 1
    
    df['month'] = df['date'].dt.month
    df['weekday'] = df['date'].dt.dayofweek
    
    df['socialEngagementType'].fillna(value=False, inplace=True)
    df['ts_isTrueDirect'].fillna(value=False, inplace=True)
    df['target'].fillna(0, inplace=True)
    df['ts_medium'].fillna('NA', inplace=True)
    df['ts_adContent'].fillna('NA', inplace=True)

# %%
true, false = True, False
data_engineering(train)

# %%
infer = pd.read_csv('../input/nput/')

# %%
def split(df, test_size=0.3):
    X = df.drop([
        'target', 'target_bool', 'visitStartTime', 'date', 'fullVisitorId', 'sessionId',
        'g_networkDomain', 'ts_referralPath', 'ts_keyword', 'ts_source', 'g_region', 'g_city', 'g_metro',
        'd_browser', 'g_region', 'socialEngagementType'
    
    ], axis=1)
    
    def encode_variables(df):
        variables = ['channelGrouping', 'g_continent', 'g_subContinent',
                     'g_country', 'ts_isTrueDirect', 'ts_medium', 'ts_campaign', 
                     'ts_adContent', 'd_operatingSystem', 'd_deviceCategory']

        for var in variables:
            df[var] = df[var].replace(False, 'False')
            df[var] = df[var].replace(True, 'True')
            encoder = preprocessing.LabelEncoder()
            encoder.fit(df[var])
            df[var] = encoder.transform(df[var])
    
    encode_variables(X)
    
    y = np.log1p(df['target'])
    
    return train_test_split(X, y, test_size=test_size, random_state=42)

# %%
X_train, X_test, y_train, y_test = split(train, 0.3)

# %%
model = xgb.XGBRegressor(max_depth=5, n_estimators=200, n_jobs=-1, nthread=8, random_state=42)

# %%
model.fit(X_train, y_train, eval_set=[(X_train, y_train)], eval_metric='rmse', early_stopping_rounds=10)
# Out:
# [0]	validation_0-rmse:1.96377
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.91608
# [2]	validation_0-rmse:1.87611
# [3]	validation_0-rmse:1.84176
# [4]	validation_0-rmse:1.81338
# [5]	validation_0-rmse:1.78973
# [6]	validation_0-rmse:1.76922
# [7]	validation_0-rmse:1.75196
# [8]	validation_0-rmse:1.73784
# [9]	validation_0-rmse:1.72555
# [10]	validation_0-rmse:1.71523
# [11]	validation_0-rmse:1.70637
# [12]	validation_0-rmse:1.69852
# [13]	validation_0-rmse:1.69209
# [14]	validation_0-rmse:1.68626
# [15]	validation_0-rmse:1.68102
# [16]	validation_0-rmse:1.67667
# [17]	validation_0-rmse:1.67259
# [18]	validation_0-rmse:1.66882
# [19]	validation_0-rmse:1.66529
# [20]	validation_0-rmse:1.66227
# [21]	validation_0-rmse:1.65973
# [22]	validation_0-rmse:1.65729
# [23]	validation_0-rmse:1.65508
# [24]	validation_0-rmse:1.65295
# [25]	validation_0-rmse:1.65078
# [26]	validation_0-rmse:1.64867
# [27]	validation_0-rmse:1.64676
# [28]	validation_0-rmse:1.64487
# [29]	validation_0-rmse:1.64355
# [30]	validation_0-rmse:1.64179
# [31]	validation_0-rmse:1.64039
# [32]	validation_0-rmse:1.63867
# [33]	validation_0-rmse:1.63732
# [34]	validation_0-rmse:1.6362
# [35]	validation_0-rmse:1.63478
# [36]	validation_0-rmse:1.63358
# [37]	validation_0-rmse:1.63229
# [38]	validation_0-rmse:1.63136
# [39]	validation_0-rmse:1.63033
# [40]	validation_0-rmse:1.62912
# [41]	validation_0-rmse:1.62824
# [42]	validation_0-rmse:1.62715
# [43]	validation_0-rmse:1.62618
# [44]	validation_0-rmse:1.62557
# [45]	validation_0-rmse:1.62471
# [46]	validation_0-rmse:1.62386
# [47]	validation_0-rmse:1.62304
# [48]	validation_0-rmse:1.62225
# [49]	validation_0-rmse:1.62141
# [50]	validation_0-rmse:1.62079
# [51]	validation_0-rmse:1.62017
# [52]	validation_0-rmse:1.61918
# [53]	validation_0-rmse:1.61788
# [54]	validation_0-rmse:1.61743
# [55]	validation_0-rmse:1.6167
# [56]	validation_0-rmse:1.61603
# [57]	validation_0-rmse:1.61495
# [58]	validation_0-rmse:1.6143
# [59]	validation_0-rmse:1.61326
# [60]	validation_0-rmse:1.61257
# [61]	validation_0-rmse:1.61184
# [62]	validation_0-rmse:1.61127
# [63]	validation_0-rmse:1.6109
# [64]	validation_0-rmse:1.61078
# [65]	validation_0-rmse:1.61028
# [66]	validation_0-rmse:1.60941
# [67]	validation_0-rmse:1.60922
# [68]	validation_0-rmse:1.60853
# [69]	validation_0-rmse:1.60774
# [70]	validation_0-rmse:1.60734
# [71]	validation_0-rmse:1.60646
# [72]	validation_0-rmse:1.6057
# [73]	validation_0-rmse:1.6052
# [74]	validation_0-rmse:1.60441
# [75]	validation_0-rmse:1.60373
# [76]	validation_0-rmse:1.60349
# [77]	validation_0-rmse:1.60333
# [78]	validation_0-rmse:1.60274
# [79]	validation_0-rmse:1.60203
# [80]	validation_0-rmse:1.60131
# [81]	validation_0-rmse:1.60079
# [82]	validation_0-rmse:1.60019
# [83]	validation_0-rmse:1.59971
# [84]	validation_0-rmse:1.59956
# [85]	validation_0-rmse:1.59891
# [86]	validation_0-rmse:1.59835
# [87]	validation_0-rmse:1.59788
# [88]	validation_0-rmse:1.59776
# [89]	validation_0-rmse:1.5975
# [90]	validation_0-rmse:1.59688
# [91]	validation_0-rmse:1.59632
# [92]	validation_0-rmse:1.59627
# [93]	validation_0-rmse:1.59582
# [94]	validation_0-rmse:1.59547
# [95]	validation_0-rmse:1.59528
# [96]	validation_0-rmse:1.59517
# [97]	validation_0-rmse:1.59482
# [98]	validation_0-rmse:1.59449
# [99]	validation_0-rmse:1.59373
# [100]	validation_0-rmse:1.59369
# [101]	validation_0-rmse:1.59307
# [102]	validation_0-rmse:1.59297
# [103]	validation_0-rmse:1.59235
# [104]	validation_0-rmse:1.59213
# [105]	validation_0-rmse:1.59144
# [106]	validation_0-rmse:1.59078
# [107]	validation_0-rmse:1.59024
# [108]	validation_0-rmse:1.59013
# [109]	validation_0-rmse:1.58962
# [110]	validation_0-rmse:1.58925
# [111]	validation_0-rmse:1.58901
# [112]	validation_0-rmse:1.58897
# [113]	validation_0-rmse:1.58874
# [114]	validation_0-rmse:1.58821
# [115]	validation_0-rmse:1.58767
# [116]	validation_0-rmse:1.58747
# [117]	validation_0-rmse:1.58739
# [118]	validation_0-rmse:1.58685
# [119]	validation_0-rmse:1.58641
# [120]	validation_0-rmse:1.58576
# [121]	validation_0-rmse:1.58549
# [122]	validation_0-rmse:1.58497
# [123]	validation_0-rmse:1.58465
# [124]	validation_0-rmse:1.5842
# [125]	validation_0-rmse:1.58412
# [126]	validation_0-rmse:1.58356
# [127]	validation_0-rmse:1.58305
# [128]	validation_0-rmse:1.58302
# [129]	validation_0-rmse:1.5828
# [130]	validation_0-rmse:1.58261
# [131]	validation_0-rmse:1.58221
# [132]	validation_0-rmse:1.58183
# [133]	validation_0-rmse:1.58165
# [134]	validation_0-rmse:1.58158
# [135]	validation_0-rmse:1.58127
# [136]	validation_0-rmse:1.58087
# [137]	validation_0-rmse:1.58084
# [138]	validation_0-rmse:1.58055
# [139]	validation_0-rmse:1.58041
# [140]	validation_0-rmse:1.57996
# [141]	validation_0-rmse:1.5799
# [142]	validation_0-rmse:1.57926
# [143]	validation_0-rmse:1.57915
# [144]	validation_0-rmse:1.57884
# [145]	validation_0-rmse:1.57841
# [146]	validation_0-rmse:1.57799
# [147]	validation_0-rmse:1.57755
# [148]	validation_0-rmse:1.57744
# [149]	validation_0-rmse:1.57736
# [150]	validation_0-rmse:1.57731
# [151]	validation_0-rmse:1.5772
# [152]	validation_0-rmse:1.57688
# [153]	validation_0-rmse:1.57633
# [154]	validation_0-rmse:1.57588
# [155]	validation_0-rmse:1.57545
# [156]	validation_0-rmse:1.57538
# [157]	validation_0-rmse:1.57513
# [158]	validation_0-rmse:1.57473
# [159]	validation_0-rmse:1.5744
# [160]	validation_0-rmse:1.57395
# [161]	validation_0-rmse:1.57348
# [162]	validation_0-rmse:1.57319
# [163]	validation_0-rmse:1.57315
# [164]	validation_0-rmse:1.57309
# [165]	validation_0-rmse:1.57266
# [166]	validation_0-rmse:1.57258
# [167]	validation_0-rmse:1.57245
# [168]	validation_0-rmse:1.57195
# [169]	validation_0-rmse:1.57192
# [170]	validation_0-rmse:1.5717
# [171]	validation_0-rmse:1.57129
# [172]	validation_0-rmse:1.57124
# [173]	validation_0-rmse:1.57109
# [174]	validation_0-rmse:1.5708
# [175]	validation_0-rmse:1.57028
# [176]	validation_0-rmse:1.57024
# [177]	validation_0-rmse:1.57011
# [178]	validation_0-rmse:1.56977
# [179]	validation_0-rmse:1.56942
# [180]	validation_0-rmse:1.56921
# [181]	validation_0-rmse:1.56918
# [182]	validation_0-rmse:1.56879
# [183]	validation_0-rmse:1.5685
# [184]	validation_0-rmse:1.56823
# [185]	validation_0-rmse:1.56793
# [186]	validation_0-rmse:1.56779
# [187]	validation_0-rmse:1.56747
# [188]	validation_0-rmse:1.56713
# [189]	validation_0-rmse:1.56696
# [190]	validation_0-rmse:1.56695
# [191]	validation_0-rmse:1.56658
# [192]	validation_0-rmse:1.56624
# [193]	validation_0-rmse:1.56612
# [194]	validation_0-rmse:1.5661
# [195]	validation_0-rmse:1.56577
# [196]	validation_0-rmse:1.56558
# [197]	validation_0-rmse:1.56528
# [198]	validation_0-rmse:1.56495
# [199]	validation_0-rmse:1.56463
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=5, min_child_weight=1, missing=None, n_estimators=200,
#        n_jobs=-1, nthread=8, objective='reg:linear', random_state=42,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
def agg(X,y):
    df = pd.merge(X,y, left_on=[''])

# %%
def aggregate_df(df):
    
    def most_common(lst):
        return max(set(lst), key=lst.count)
    
    agg = pd.DataFrame(data=df['fullVisitorId'].unique(), columns=['fullVisitorId'])
    
    agg = pd.merge(
            agg, 
            np.log1p(df.groupby('fullVisitorId')['target'].sum()).to_frame(), 
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    agg = pd.merge(
            agg, 
            df.groupby('fullVisitorId')['sessionId'].count().to_frame(), 
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    agg = pd.merge(
            agg, 
            df.groupby('fullVisitorId')['target_bool'].sum().to_frame(), 
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    agg = pd.merge(
            agg,
            df.groupby('fullVisitorId')['g_country'].apply(lambda x: most_common(x.values.tolist())).to_frame(),
            left_on='fullVisitorId', 
            right_on='fullVisitorId')
    
    train.groupby('fullVisitorId')['g_country'].apply(lambda x: most_common(x.values.tolist()))
    
    agg.columns = ['fullVisitorId', 'target', 'num_sess', 'num_deals', 'country']
    
    return agg
